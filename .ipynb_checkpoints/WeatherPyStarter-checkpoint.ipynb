# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
'''
City          535
Cloudiness    535
Country       535
Date          535
Humidity      535
Lat           535
Lng           535
Max Temp      535
Wind Speed    535
'''

# %%
for item in cities:
    print(item)
# Out:
# saint-philippe
# punta arenas
# nanakuli
# mahebourg
# kuruman
# cidreira
# yellowknife
# nikolskoye
# rikitea
# acuna
# shieli
# norman wells
# ambovombe
# bilibino
# faya
# mataura
# sedelnikovo
# salaga
# daru
# half moon bay
# jamestown
# te anau
# sao filipe
# carnarvon
# kirkwall
# neuquen
# pitsunda
# tuktoyaktuk
# copalillo
# ust-bolsheretsk
# ucluelet
# busselton
# jahrom
# hermanus
# lodwar
# murdochville
# bethel
# nanortalik
# port elizabeth
# rio gallegos
# nikolsk
# kapaa
# severo-kurilsk
# klaksvik
# saskylakh
# upernavik
# malakal
# east london
# georgetown
# bredasdorp
# along
# saint-pierre
# albany
# tyup
# butaritari
# quesnel
# cabo san lucas
# illoqqortoormiut
# puerto ayora
# buta
# taolanaro
# vylgort
# haines junction
# cherskiy
# agadir
# cape town
# bekhtery
# grindavik
# daoukro
# college
# sibu
# bengkulu
# ushuaia
# puerto colombia
# qaanaaq
# attawapiskat
# kango
# lavrentiya
# maarianhamina
# marica
# salinas
# adrar
# chupa
# byron bay
# vaini
# asuncion nochixtlan
# khatanga
# vianopolis
# camana
# sungaipenuh
# roma
# constitucion
# itoman
# guerrero negro
# gubkinskiy
# bluff
# sogdiondon
# cockburn town
# gorin
# uyuni
# viransehir
# kirakira
# portland
# sao raimundo nonato
# barentsburg
# airai
# ngunguru
# hilo
# itarema
# chokurdakh
# pevek
# ziarat
# ribeira grande
# kendal
# grandview
# nizhneyansk
# chodavaram
# amderma
# barawe
# saleaula
# la asuncion
# saint george
# mujiayingzi
# sitka
# narsaq
# port alfred
# hovd
# toulepleu
# abha
# muhos
# hithadhoo
# pisco
# kyshtovka
# binzhou
# hoshcha
# avarua
# yulara
# lebu
# shanhetun
# vardo
# lorengau
# nemuro
# qaqortoq
# conceicao do araguaia
# manta
# amstetten
# verkhnyaya inta
# inverell
# talnakh
# pokanayevka
# tiquicheo
# tela
# hobart
# bambous virieux
# ponta do sol
# esperance
# tasiilaq
# avera
# chuy
# victoria
# louisbourg
# belushya guba
# muli
# takoradi
# tommot
# maragogi
# padang
# bonavista
# qui nhon
# tazovskiy
# port lincoln
# baykit
# faanui
# new norfolk
# mehamn
# dikson
# motygino
# kavieng
# fairbanks
# vilyuysk
# krasnoselkup
# mollendo
# kodiak
# grand gaube
# acarau
# miri
# enkhuizen
# tuatapere
# jiwani
# bathsheba
# churapcha
# santa maria
# ulaangom
# barrow
# vestmannaeyjar
# opuwo
# vila franca do campo
# moose factory
# olinda
# roald
# caraballeda
# aklavik
# benxi
# udachnyy
# milkovo
# samarai
# mar del plata
# karkaralinsk
# sangar
# cavalcante
# hofn
# torbay
# kalmunai
# nome
# atuona
# anadyr
# boden
# waipawa
# salalah
# gao
# bandarbeyla
# isangel
# hammerfest
# talakan
# naze
# bani walid
# macapa
# dingle
# vaitupu
# lasa
# tyulgan
# thompson
# donskoy
# soavinandriana
# samusu
# krasnyy yar
# north bend
# jalu
# provideniya
# benguela
# vostok
# ayan
# eyl
# pilar
# lamesa
# lata
# tricase
# hualmay
# portree
# kruisfontein
# tres arroyos
# acapulco
# mananara
# la rioja
# chagda
# umzimvubu
# lulea
# russell
# isla vista
# phrai bung
# kasempa
# ilulissat
# sentyabrskiy
# galle
# grand river south east
# tumpat
# fortuna
# mayo
# taoudenni
# chato
# sao sepe
# rawson
# aflu
# biak
# ostrovnoy
# mount gambier
# baturinskaya
# hasaki
# vestmanna
# san carlos de bariloche
# westport
# newton
# maki
# akyab
# dubbo
# komsomolskiy
# tapaua
# aykhal
# talaya
# andarab
# iquique
# arraial do cabo
# tiksi
# luderitz
# raudeberg
# belyy yar
# pangnirtung
# hami
# coihueco
# codrington
# castro
# lillehammer
# semey
# bismarck
# mudbidri
# mys shmidta
# port blair
# polovinnoye
# longyearbyen
# sao joao da barra
# hayden
# brunico
# souillac
# menongue
# gornopravdinsk
# tungkang
# erdenet
# cayenne
# sarangani
# bilma
# geraldton
# batsfjord
# carutapera
# leningradskiy
# nguiu
# kununurra
# berbera
# zhigansk
# ahipara
# searcy
# tsihombe
# shaoyang
# keflavik
# mahaicony
# whitecourt
# natal
# shuyskoye
# batagay-alyta
# huarmey
# mullaitivu
# negombo
# pingshan
# adre
# buraydah
# bintulu
# lagoa
# kinablangan
# nizwa
# bamako
# ciudad guayana
# pochutla
# majene
# husavik
# pavlikeni
# petrove
# walvis bay
# beringovskiy
# los llanos de aridane
# cruden bay
# deputatskiy
# corsicana
# banda aceh
# santa cruz
# shirgaon
# limon
# barranca
# nagato
# tessalit
# sioux lookout
# fukuma
# praya
# marzuq
# sorland
# elat
# katsuura
# rio grande
# benicarlo
# marsa matruh
# alofi
# funtua
# shangrao
# okhotsk
# oyon
# finschhafen
# dudinka
# university place
# coihaique
# marcona
# dutse
# meadow lake
# at-bashi
# paragominas
# vila
# kizema
# turukhansk
# rosita
# parati
# terrace
# buala
# bairiki
# san pedro
# sarkand
# tiznit
# west odessa
# euclides da cunha
# iqaluit
# ipixuna
# tumannyy
# valpacos
# mamakan
# maceio
# nangomba
# cabedelo
# riachao das neves
# saldanha
# ketchikan
# kaitangata
# mairana
# coquimbo
# yinchuan
# fort nelson
# manakara
# ryotsu
# bur gabo
# niort
# yar-sale
# vila velha
# sola
# valdivia
# aracati
# riyadh
# sao felix do xingu
# chernyshevskiy
# elliot
# salekhard
# ambon
# lolua
# san quintin
# novokuznetsk
# mao
# omsukchan
# comodoro rivadavia
# petropavlovsk-kamchatskiy
# malanville
# san vicente
# sajanan
# jinchang
# clyde river
# nadym
# batemans bay
# kolyvan
# kamaishi
# ban dung
# bolobo
# thanh hoa
# betafo
# poum
# bestobe
# miraflores
# roebourne
# pascagoula
# marshall
# jombang
# karratha
# kahului
# lompoc
# bembereke
# namatanai
# kushtagi
# oranjemund
# kobryn
# lundazi
# westerland
# sampit
# chabahar
# darnah
# wattegama
# maltahohe
# manzhouli
# lalmohan
# mangrol
# san cristobal
# gravelbourg
# phan thiet
# conway
# maniitsoq
# karaul
# sandovo
# wajima
# sorong
# korla
# narrabri
# longlac
# funadhoo
# aruja
# shirokiy
# stolin
# xifeng
# taklisah
# dodge city
# richards bay
# arlit
# palabuhanratu
# south sioux city
# calamar
# andenes
# barra patuca
# ternate
# bucerias
# melendugno
# semirom
# caravelas
# la ronge
# laguna
# viligili
# hamilton
# bronnoysund
# antananarivo
# fort saint john
# ancud
# kamenka
# halalo
# mrirt
# alice springs
# mirina
# manaure
# casa nova
# cartagena
# macon
# matagami
# mackenzie
# sakakah
# farah
# hede
# tete
# medicine hat
# grosseto
# bataipora
# broome
# smithers
# almaznyy
# puerto madryn
# havelock
# sao jose da coroa grande
# cam ranh
# belmonte
# mackay
# sumbawa
# talawdi
# satun
# peleduy
# mumford
# flinders
# cagayan de tawi-tawi
# galesong
# marfino
# archidona
# emerald
# qostanay
# chara
# auki
# sosnovskiy
# asfi
# saint simons
# cetraro
# loule
# invermere
# nuuk
# korgen
# minden
# saint-augustin
# mergui
# olafsvik
# labuhan
# magdagachi
# atar
# balaguer
# hailar
# manoel urbano
# tahe
# kunya
# mount isa
# palmer
# tanete
# margate
# saint-denis
# marevo
# asau
# saint stephen
# antequera
# srednekolymsk
# karaton
# mecca
# yining
# anar darreh
# mae hong son
# makakilo city
# bihoro
# floresta
# taclobo
# san patricio
# uppsala
# nieuw nickerie
# ugento
# derzhavinsk
# kilcock
# buochs
# utiroa
# fairlie

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = url + "appid=" + weather_api_key + "&q=" + cities[0]
response = requests.get(query_url).json()
response
# Out:
# {'coord': {'lon': 55.77, 'lat': -21.36},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 297.51,
#   'feels_like': 293.92,
#   'temp_min': 293.15,
#   'temp_max': 300.15,
#   'pressure': 1008,
#   'humidity': 69},
#  'visibility': 10000,
#  'wind': {'speed': 9.3, 'deg': 110},
#  'clouds': {'all': 75},
#  'dt': 1583895274,
#  'sys': {'type': 1,
#   'id': 2127,
#   'country': 'RE',
#   'sunrise': 1583893067,
#   'sunset': 1583937371},
#  'timezone': 14400,
#  'id': 935215,
#  'name': 'Saint-Philippe',
#  'cod': 200}

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
data = {"City": [],
       "Cloudiness": [],
       "Country": [],
       "Date": [],
       "Humidity": [],
       "Lat": [],
       "Lng": [],
       "Max Temp": [],
       "Wind Speed": []}

number = 0
sets = 0

for item in cities:
    try:
        query_url = f"{url}appid={weather_api_key}&q={item}"
        response = requests.get(query_url).json()
        number = number + 1
        print(f"Processing Record {number} of Set {sets} | {item}")
        data["City"].append(response['name'])
        data["Cloudiness"].append(response['clouds']['all'])
        data["Country"].append(response['sys']['country'])
        data["Date"].append(response['dt'])
        data["Humidity"].append(response['main']['humidity'])
        data["Lat"].append(response['coord']['lat'])
        data["Lng"].append(response['coord']['lon'])
        data["Max Temp"].append(response['main']['temp_max'])
        data["Wind Speed"].append(response['wind']['speed'])
    except:
        print("City not found. Skipping ...")
    if number == 50:
        sets = sets+1
        number = 0
data
# Out:
# Processing Record 1 of Set 0 | saint-philippe
# Processing Record 2 of Set 0 | punta arenas
# Processing Record 3 of Set 0 | nanakuli
# Processing Record 4 of Set 0 | mahebourg
# Processing Record 5 of Set 0 | kuruman
# Processing Record 6 of Set 0 | cidreira
# Processing Record 7 of Set 0 | yellowknife
# Processing Record 8 of Set 0 | nikolskoye
# Processing Record 9 of Set 0 | rikitea
# Processing Record 10 of Set 0 | acuna
# City not found. Skipping ...
# Processing Record 11 of Set 0 | shieli
# Processing Record 12 of Set 0 | norman wells
# Processing Record 13 of Set 0 | ambovombe
# Processing Record 14 of Set 0 | bilibino
# Processing Record 15 of Set 0 | faya
# Processing Record 16 of Set 0 | mataura
# Processing Record 17 of Set 0 | sedelnikovo
# City not found. Skipping ...
# Processing Record 18 of Set 0 | salaga
# Processing Record 19 of Set 0 | daru
# Processing Record 20 of Set 0 | half moon bay
# Processing Record 21 of Set 0 | jamestown
# Processing Record 22 of Set 0 | te anau
# Processing Record 23 of Set 0 | sao filipe
# Processing Record 24 of Set 0 | carnarvon
# Processing Record 25 of Set 0 | kirkwall
# Processing Record 26 of Set 0 | neuquen
# Processing Record 27 of Set 0 | pitsunda
# Processing Record 28 of Set 0 | tuktoyaktuk
# Processing Record 29 of Set 0 | copalillo
# Processing Record 30 of Set 0 | ust-bolsheretsk
# City not found. Skipping ...
# Processing Record 31 of Set 0 | ucluelet
# Processing Record 32 of Set 0 | busselton
# Processing Record 33 of Set 0 | jahrom
# City not found. Skipping ...
# Processing Record 34 of Set 0 | hermanus
# Processing Record 35 of Set 0 | lodwar
# Processing Record 36 of Set 0 | murdochville
# Processing Record 37 of Set 0 | bethel
# Processing Record 38 of Set 0 | nanortalik
# Processing Record 39 of Set 0 | port elizabeth
# Processing Record 40 of Set 0 | rio gallegos
# Processing Record 41 of Set 0 | nikolsk
# Processing Record 42 of Set 0 | kapaa
# Processing Record 43 of Set 0 | severo-kurilsk
# Processing Record 44 of Set 0 | klaksvik
# Processing Record 45 of Set 0 | saskylakh
# Processing Record 46 of Set 0 | upernavik
# Processing Record 47 of Set 0 | malakal
# Processing Record 48 of Set 0 | east london
# Processing Record 49 of Set 0 | georgetown
# Processing Record 50 of Set 0 | bredasdorp
# Processing Record 1 of Set 1 | along
# Processing Record 2 of Set 1 | saint-pierre
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | tyup
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | quesnel
# Processing Record 7 of Set 1 | cabo san lucas
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping ...
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | buta
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping ...
# Processing Record 12 of Set 1 | vylgort
# City not found. Skipping ...
# Processing Record 13 of Set 1 | haines junction
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | agadir
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | bekhtery
# Processing Record 18 of Set 1 | grindavik
# Processing Record 19 of Set 1 | daoukro
# Processing Record 20 of Set 1 | college
# Processing Record 21 of Set 1 | sibu
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | puerto colombia
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | attawapiskat
# City not found. Skipping ...
# Processing Record 27 of Set 1 | kango
# Processing Record 28 of Set 1 | lavrentiya
# Processing Record 29 of Set 1 | maarianhamina
# Processing Record 30 of Set 1 | marica
# Processing Record 31 of Set 1 | salinas
# Processing Record 32 of Set 1 | adrar
# Processing Record 33 of Set 1 | chupa
# Processing Record 34 of Set 1 | byron bay
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | asuncion nochixtlan
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | vianopolis
# Processing Record 39 of Set 1 | camana
# Processing Record 40 of Set 1 | sungaipenuh
# Processing Record 41 of Set 1 | roma
# Processing Record 42 of Set 1 | constitucion
# Processing Record 43 of Set 1 | itoman
# Processing Record 44 of Set 1 | guerrero negro
# Processing Record 45 of Set 1 | gubkinskiy
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | sogdiondon
# City not found. Skipping ...
# Processing Record 48 of Set 1 | cockburn town
# Processing Record 49 of Set 1 | gorin
# Processing Record 50 of Set 1 | uyuni
# Processing Record 1 of Set 2 | viransehir
# Processing Record 2 of Set 2 | kirakira
# Processing Record 3 of Set 2 | portland
# Processing Record 4 of Set 2 | sao raimundo nonato
# Processing Record 5 of Set 2 | barentsburg
# City not found. Skipping ...
# Processing Record 6 of Set 2 | airai
# Processing Record 7 of Set 2 | ngunguru
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | itarema
# Processing Record 10 of Set 2 | chokurdakh
# Processing Record 11 of Set 2 | pevek
# Processing Record 12 of Set 2 | ziarat
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | kendal
# Processing Record 15 of Set 2 | grandview
# Processing Record 16 of Set 2 | nizhneyansk
# City not found. Skipping ...
# Processing Record 17 of Set 2 | chodavaram
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping ...
# Processing Record 19 of Set 2 | barawe
# City not found. Skipping ...
# Processing Record 20 of Set 2 | saleaula
# City not found. Skipping ...
# Processing Record 21 of Set 2 | la asuncion
# Processing Record 22 of Set 2 | saint george
# Processing Record 23 of Set 2 | mujiayingzi
# Processing Record 24 of Set 2 | sitka
# Processing Record 25 of Set 2 | narsaq
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | hovd
# Processing Record 28 of Set 2 | toulepleu
# City not found. Skipping ...
# Processing Record 29 of Set 2 | abha
# Processing Record 30 of Set 2 | muhos
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | pisco
# Processing Record 33 of Set 2 | kyshtovka
# Processing Record 34 of Set 2 | binzhou
# Processing Record 35 of Set 2 | hoshcha
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | yulara
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | shanhetun
# Processing Record 40 of Set 2 | vardo
# Processing Record 41 of Set 2 | lorengau
# Processing Record 42 of Set 2 | nemuro
# Processing Record 43 of Set 2 | qaqortoq
# Processing Record 44 of Set 2 | conceicao do araguaia
# Processing Record 45 of Set 2 | manta
# Processing Record 46 of Set 2 | amstetten
# Processing Record 47 of Set 2 | verkhnyaya inta
# Processing Record 48 of Set 2 | inverell
# Processing Record 49 of Set 2 | talnakh
# Processing Record 50 of Set 2 | pokanayevka
# City not found. Skipping ...
# Processing Record 1 of Set 3 | tiquicheo
# Processing Record 2 of Set 3 | tela
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | bambous virieux
# Processing Record 5 of Set 3 | ponta do sol
# Processing Record 6 of Set 3 | esperance
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | avera
# Processing Record 9 of Set 3 | chuy
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | louisbourg
# City not found. Skipping ...
# Processing Record 12 of Set 3 | belushya guba
# City not found. Skipping ...
# Processing Record 13 of Set 3 | muli
# Processing Record 14 of Set 3 | takoradi
# Processing Record 15 of Set 3 | tommot
# Processing Record 16 of Set 3 | maragogi
# Processing Record 17 of Set 3 | padang
# Processing Record 18 of Set 3 | bonavista
# Processing Record 19 of Set 3 | qui nhon
# Processing Record 20 of Set 3 | tazovskiy
# Processing Record 21 of Set 3 | port lincoln
# Processing Record 22 of Set 3 | baykit
# Processing Record 23 of Set 3 | faanui
# Processing Record 24 of Set 3 | new norfolk
# Processing Record 25 of Set 3 | mehamn
# Processing Record 26 of Set 3 | dikson
# Processing Record 27 of Set 3 | motygino
# Processing Record 28 of Set 3 | kavieng
# Processing Record 29 of Set 3 | fairbanks
# Processing Record 30 of Set 3 | vilyuysk
# Processing Record 31 of Set 3 | krasnoselkup
# Processing Record 32 of Set 3 | mollendo
# Processing Record 33 of Set 3 | kodiak
# Processing Record 34 of Set 3 | grand gaube
# Processing Record 35 of Set 3 | acarau
# Processing Record 36 of Set 3 | miri
# Processing Record 37 of Set 3 | enkhuizen
# Processing Record 38 of Set 3 | tuatapere
# Processing Record 39 of Set 3 | jiwani
# Processing Record 40 of Set 3 | bathsheba
# Processing Record 41 of Set 3 | churapcha
# Processing Record 42 of Set 3 | santa maria
# Processing Record 43 of Set 3 | ulaangom
# Processing Record 44 of Set 3 | barrow
# Processing Record 45 of Set 3 | vestmannaeyjar
# Processing Record 46 of Set 3 | opuwo
# Processing Record 47 of Set 3 | vila franca do campo
# Processing Record 48 of Set 3 | moose factory
# Processing Record 49 of Set 3 | olinda
# Processing Record 50 of Set 3 | roald
# Processing Record 1 of Set 4 | caraballeda
# Processing Record 2 of Set 4 | aklavik
# Processing Record 3 of Set 4 | benxi
# Processing Record 4 of Set 4 | udachnyy
# Processing Record 5 of Set 4 | milkovo
# Processing Record 6 of Set 4 | samarai
# Processing Record 7 of Set 4 | mar del plata
# Processing Record 8 of Set 4 | karkaralinsk
# City not found. Skipping ...
# Processing Record 9 of Set 4 | sangar
# Processing Record 10 of Set 4 | cavalcante
# Processing Record 11 of Set 4 | hofn
# Processing Record 12 of Set 4 | torbay
# Processing Record 13 of Set 4 | kalmunai
# Processing Record 14 of Set 4 | nome
# Processing Record 15 of Set 4 | atuona
# Processing Record 16 of Set 4 | anadyr
# Processing Record 17 of Set 4 | boden
# Processing Record 18 of Set 4 | waipawa
# Processing Record 19 of Set 4 | salalah
# Processing Record 20 of Set 4 | gao
# Processing Record 21 of Set 4 | bandarbeyla
# Processing Record 22 of Set 4 | isangel
# Processing Record 23 of Set 4 | hammerfest
# Processing Record 24 of Set 4 | talakan
# Processing Record 25 of Set 4 | naze
# Processing Record 26 of Set 4 | bani walid
# Processing Record 27 of Set 4 | macapa
# Processing Record 28 of Set 4 | dingle
# Processing Record 29 of Set 4 | vaitupu
# City not found. Skipping ...
# Processing Record 30 of Set 4 | lasa
# Processing Record 31 of Set 4 | tyulgan
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | donskoy
# Processing Record 34 of Set 4 | soavinandriana
# Processing Record 35 of Set 4 | samusu
# City not found. Skipping ...
# Processing Record 36 of Set 4 | krasnyy yar
# Processing Record 37 of Set 4 | north bend
# Processing Record 38 of Set 4 | jalu
# Processing Record 39 of Set 4 | provideniya
# Processing Record 40 of Set 4 | benguela
# Processing Record 41 of Set 4 | vostok
# Processing Record 42 of Set 4 | ayan
# Processing Record 43 of Set 4 | eyl
# Processing Record 44 of Set 4 | pilar
# Processing Record 45 of Set 4 | lamesa
# Processing Record 46 of Set 4 | lata
# Processing Record 47 of Set 4 | tricase
# Processing Record 48 of Set 4 | hualmay
# Processing Record 49 of Set 4 | portree
# Processing Record 50 of Set 4 | kruisfontein
# Processing Record 1 of Set 5 | tres arroyos
# Processing Record 2 of Set 5 | acapulco
# Processing Record 3 of Set 5 | mananara
# Processing Record 4 of Set 5 | la rioja
# Processing Record 5 of Set 5 | chagda
# City not found. Skipping ...
# Processing Record 6 of Set 5 | umzimvubu
# City not found. Skipping ...
# Processing Record 7 of Set 5 | lulea
# Processing Record 8 of Set 5 | russell
# Processing Record 9 of Set 5 | isla vista
# Processing Record 10 of Set 5 | phrai bung
# City not found. Skipping ...
# Processing Record 11 of Set 5 | kasempa
# Processing Record 12 of Set 5 | ilulissat
# Processing Record 13 of Set 5 | sentyabrskiy
# City not found. Skipping ...
# Processing Record 14 of Set 5 | galle
# Processing Record 15 of Set 5 | grand river south east
# City not found. Skipping ...
# Processing Record 16 of Set 5 | tumpat
# Processing Record 17 of Set 5 | fortuna
# Processing Record 18 of Set 5 | mayo
# Processing Record 19 of Set 5 | taoudenni
# Processing Record 20 of Set 5 | chato
# Processing Record 21 of Set 5 | sao sepe
# Processing Record 22 of Set 5 | rawson
# Processing Record 23 of Set 5 | aflu
# City not found. Skipping ...
# Processing Record 24 of Set 5 | biak
# Processing Record 25 of Set 5 | ostrovnoy
# Processing Record 26 of Set 5 | mount gambier
# Processing Record 27 of Set 5 | baturinskaya
# Processing Record 28 of Set 5 | hasaki
# Processing Record 29 of Set 5 | vestmanna
# Processing Record 30 of Set 5 | san carlos de bariloche
# Processing Record 31 of Set 5 | westport
# Processing Record 32 of Set 5 | newton
# Processing Record 33 of Set 5 | maki
# Processing Record 34 of Set 5 | akyab
# Processing Record 35 of Set 5 | dubbo
# Processing Record 36 of Set 5 | komsomolskiy
# Processing Record 37 of Set 5 | tapaua
# City not found. Skipping ...
# Processing Record 38 of Set 5 | aykhal
# Processing Record 39 of Set 5 | talaya
# Processing Record 40 of Set 5 | andarab
# City not found. Skipping ...
# Processing Record 41 of Set 5 | iquique
# Processing Record 42 of Set 5 | arraial do cabo
# Processing Record 43 of Set 5 | tiksi
# Processing Record 44 of Set 5 | luderitz
# Processing Record 45 of Set 5 | raudeberg
# Processing Record 46 of Set 5 | belyy yar
# Processing Record 47 of Set 5 | pangnirtung
# Processing Record 48 of Set 5 | hami
# Processing Record 49 of Set 5 | coihueco
# Processing Record 50 of Set 5 | codrington
# Processing Record 1 of Set 6 | castro
# Processing Record 2 of Set 6 | lillehammer
# Processing Record 3 of Set 6 | semey
# Processing Record 4 of Set 6 | bismarck
# Processing Record 5 of Set 6 | mudbidri
# Processing Record 6 of Set 6 | mys shmidta
# City not found. Skipping ...
# Processing Record 7 of Set 6 | port blair
# Processing Record 8 of Set 6 | polovinnoye
# Processing Record 9 of Set 6 | longyearbyen
# Processing Record 10 of Set 6 | sao joao da barra
# Processing Record 11 of Set 6 | hayden
# Processing Record 12 of Set 6 | brunico
# Processing Record 13 of Set 6 | souillac
# Processing Record 14 of Set 6 | menongue
# Processing Record 15 of Set 6 | gornopravdinsk
# Processing Record 16 of Set 6 | tungkang
# City not found. Skipping ...
# Processing Record 17 of Set 6 | erdenet
# Processing Record 18 of Set 6 | cayenne
# Processing Record 19 of Set 6 | sarangani
# Processing Record 20 of Set 6 | bilma
# Processing Record 21 of Set 6 | geraldton
# Processing Record 22 of Set 6 | batsfjord
# Processing Record 23 of Set 6 | carutapera
# Processing Record 24 of Set 6 | leningradskiy
# Processing Record 25 of Set 6 | nguiu
# City not found. Skipping ...
# Processing Record 26 of Set 6 | kununurra
# Processing Record 27 of Set 6 | berbera
# Processing Record 28 of Set 6 | zhigansk
# Processing Record 29 of Set 6 | ahipara
# Processing Record 30 of Set 6 | searcy
# Processing Record 31 of Set 6 | tsihombe
# City not found. Skipping ...
# Processing Record 32 of Set 6 | shaoyang
# Processing Record 33 of Set 6 | keflavik
# Processing Record 34 of Set 6 | mahaicony
# City not found. Skipping ...
# Processing Record 35 of Set 6 | whitecourt
# Processing Record 36 of Set 6 | natal
# Processing Record 37 of Set 6 | shuyskoye
# Processing Record 38 of Set 6 | batagay-alyta
# Processing Record 39 of Set 6 | huarmey
# Processing Record 40 of Set 6 | mullaitivu
# City not found. Skipping ...
# Processing Record 41 of Set 6 | negombo
# Processing Record 42 of Set 6 | pingshan
# Processing Record 43 of Set 6 | adre
# Processing Record 44 of Set 6 | buraydah
# Processing Record 45 of Set 6 | bintulu
# Processing Record 46 of Set 6 | lagoa
# Processing Record 47 of Set 6 | kinablangan
# Processing Record 48 of Set 6 | nizwa
# Processing Record 49 of Set 6 | bamako
# Processing Record 50 of Set 6 | ciudad guayana
# Processing Record 1 of Set 7 | pochutla
# Processing Record 2 of Set 7 | majene
# Processing Record 3 of Set 7 | husavik
# Processing Record 4 of Set 7 | pavlikeni
# Processing Record 5 of Set 7 | petrove
# Processing Record 6 of Set 7 | walvis bay
# Processing Record 7 of Set 7 | beringovskiy
# Processing Record 8 of Set 7 | los llanos de aridane
# Processing Record 9 of Set 7 | cruden bay
# City not found. Skipping ...
# Processing Record 10 of Set 7 | deputatskiy
# Processing Record 11 of Set 7 | corsicana
# Processing Record 12 of Set 7 | banda aceh
# Processing Record 13 of Set 7 | santa cruz
# Processing Record 14 of Set 7 | shirgaon
# Processing Record 15 of Set 7 | limon
# Processing Record 16 of Set 7 | barranca
# Processing Record 17 of Set 7 | nagato
# Processing Record 18 of Set 7 | tessalit
# Processing Record 19 of Set 7 | sioux lookout
# Processing Record 20 of Set 7 | fukuma
# Processing Record 21 of Set 7 | praya
# Processing Record 22 of Set 7 | marzuq
# Processing Record 23 of Set 7 | sorland
# Processing Record 24 of Set 7 | elat
# Processing Record 25 of Set 7 | katsuura
# Processing Record 26 of Set 7 | rio grande
# Processing Record 27 of Set 7 | benicarlo
# Processing Record 28 of Set 7 | marsa matruh
# Processing Record 29 of Set 7 | alofi
# Processing Record 30 of Set 7 | funtua
# Processing Record 31 of Set 7 | shangrao
# Processing Record 32 of Set 7 | okhotsk
# Processing Record 33 of Set 7 | oyon
# Processing Record 34 of Set 7 | finschhafen
# Processing Record 35 of Set 7 | dudinka
# Processing Record 36 of Set 7 | university place
# Processing Record 37 of Set 7 | coihaique
# Processing Record 38 of Set 7 | marcona
# City not found. Skipping ...
# Processing Record 39 of Set 7 | dutse
# Processing Record 40 of Set 7 | meadow lake
# Processing Record 41 of Set 7 | at-bashi
# Processing Record 42 of Set 7 | paragominas
# Processing Record 43 of Set 7 | vila
# Processing Record 44 of Set 7 | kizema
# Processing Record 45 of Set 7 | turukhansk
# Processing Record 46 of Set 7 | rosita
# Processing Record 47 of Set 7 | parati
# Processing Record 48 of Set 7 | terrace
# Processing Record 49 of Set 7 | buala
# Processing Record 50 of Set 7 | bairiki
# Processing Record 1 of Set 8 | san pedro
# Processing Record 2 of Set 8 | sarkand
# Processing Record 3 of Set 8 | tiznit
# Processing Record 4 of Set 8 | west odessa
# Processing Record 5 of Set 8 | euclides da cunha
# Processing Record 6 of Set 8 | iqaluit
# Processing Record 7 of Set 8 | ipixuna
# Processing Record 8 of Set 8 | tumannyy
# City not found. Skipping ...
# Processing Record 9 of Set 8 | valpacos
# Processing Record 10 of Set 8 | mamakan
# Processing Record 11 of Set 8 | maceio
# Processing Record 12 of Set 8 | nangomba
# Processing Record 13 of Set 8 | cabedelo
# Processing Record 14 of Set 8 | riachao das neves
# Processing Record 15 of Set 8 | saldanha
# Processing Record 16 of Set 8 | ketchikan
# Processing Record 17 of Set 8 | kaitangata
# Processing Record 18 of Set 8 | mairana
# Processing Record 19 of Set 8 | coquimbo
# Processing Record 20 of Set 8 | yinchuan
# Processing Record 21 of Set 8 | fort nelson
# Processing Record 22 of Set 8 | manakara
# Processing Record 23 of Set 8 | ryotsu
# Processing Record 24 of Set 8 | bur gabo
# City not found. Skipping ...
# Processing Record 25 of Set 8 | niort
# Processing Record 26 of Set 8 | yar-sale
# Processing Record 27 of Set 8 | vila velha
# Processing Record 28 of Set 8 | sola
# Processing Record 29 of Set 8 | valdivia
# Processing Record 30 of Set 8 | aracati
# Processing Record 31 of Set 8 | riyadh
# Processing Record 32 of Set 8 | sao felix do xingu
# Processing Record 33 of Set 8 | chernyshevskiy
# Processing Record 34 of Set 8 | elliot
# Processing Record 35 of Set 8 | salekhard
# Processing Record 36 of Set 8 | ambon
# Processing Record 37 of Set 8 | lolua
# City not found. Skipping ...
# Processing Record 38 of Set 8 | san quintin
# Processing Record 39 of Set 8 | novokuznetsk
# Processing Record 40 of Set 8 | mao
# Processing Record 41 of Set 8 | omsukchan
# Processing Record 42 of Set 8 | comodoro rivadavia
# Processing Record 43 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 8 | malanville
# Processing Record 45 of Set 8 | san vicente
# Processing Record 46 of Set 8 | sajanan
# Processing Record 47 of Set 8 | jinchang
# Processing Record 48 of Set 8 | clyde river
# Processing Record 49 of Set 8 | nadym
# Processing Record 50 of Set 8 | batemans bay
# Processing Record 1 of Set 9 | kolyvan
# Processing Record 2 of Set 9 | kamaishi
# Processing Record 3 of Set 9 | ban dung
# Processing Record 4 of Set 9 | bolobo
# Processing Record 5 of Set 9 | thanh hoa
# Processing Record 6 of Set 9 | betafo
# Processing Record 7 of Set 9 | poum
# Processing Record 8 of Set 9 | bestobe
# Processing Record 9 of Set 9 | miraflores
# Processing Record 10 of Set 9 | roebourne
# Processing Record 11 of Set 9 | pascagoula
# Processing Record 12 of Set 9 | marshall
# Processing Record 13 of Set 9 | jombang
# Processing Record 14 of Set 9 | karratha
# Processing Record 15 of Set 9 | kahului
# Processing Record 16 of Set 9 | lompoc
# Processing Record 17 of Set 9 | bembereke
# Processing Record 18 of Set 9 | namatanai
# Processing Record 19 of Set 9 | kushtagi
# Processing Record 20 of Set 9 | oranjemund
# Processing Record 21 of Set 9 | kobryn
# Processing Record 22 of Set 9 | lundazi
# Processing Record 23 of Set 9 | westerland
# Processing Record 24 of Set 9 | sampit
# Processing Record 25 of Set 9 | chabahar
# Processing Record 26 of Set 9 | darnah
# Processing Record 27 of Set 9 | wattegama
# Processing Record 28 of Set 9 | maltahohe
# Processing Record 29 of Set 9 | manzhouli
# Processing Record 30 of Set 9 | lalmohan
# Processing Record 31 of Set 9 | mangrol
# Processing Record 32 of Set 9 | san cristobal
# Processing Record 33 of Set 9 | gravelbourg
# Processing Record 34 of Set 9 | phan thiet
# Processing Record 35 of Set 9 | conway
# Processing Record 36 of Set 9 | maniitsoq
# Processing Record 37 of Set 9 | karaul
# City not found. Skipping ...
# Processing Record 38 of Set 9 | sandovo
# Processing Record 39 of Set 9 | wajima
# Processing Record 40 of Set 9 | sorong
# Processing Record 41 of Set 9 | korla
# Processing Record 42 of Set 9 | narrabri
# Processing Record 43 of Set 9 | longlac
# City not found. Skipping ...
# Processing Record 44 of Set 9 | funadhoo
# Processing Record 45 of Set 9 | aruja
# Processing Record 46 of Set 9 | shirokiy
# Processing Record 47 of Set 9 | stolin
# Processing Record 48 of Set 9 | xifeng
# Processing Record 49 of Set 9 | taklisah
# Processing Record 50 of Set 9 | dodge city
# Processing Record 1 of Set 10 | richards bay
# Processing Record 2 of Set 10 | arlit
# Processing Record 3 of Set 10 | palabuhanratu
# City not found. Skipping ...
# Processing Record 4 of Set 10 | south sioux city
# Processing Record 5 of Set 10 | calamar
# Processing Record 6 of Set 10 | andenes
# Processing Record 7 of Set 10 | barra patuca
# Processing Record 8 of Set 10 | ternate
# Processing Record 9 of Set 10 | bucerias
# Processing Record 10 of Set 10 | melendugno
# Processing Record 11 of Set 10 | semirom
# Processing Record 12 of Set 10 | caravelas
# Processing Record 13 of Set 10 | la ronge
# Processing Record 14 of Set 10 | laguna
# Processing Record 15 of Set 10 | viligili
# City not found. Skipping ...
# Processing Record 16 of Set 10 | hamilton
# Processing Record 17 of Set 10 | bronnoysund
# Processing Record 18 of Set 10 | antananarivo
# Processing Record 19 of Set 10 | fort saint john
# City not found. Skipping ...
# Processing Record 20 of Set 10 | ancud
# Processing Record 21 of Set 10 | kamenka
# Processing Record 22 of Set 10 | halalo
# City not found. Skipping ...
# Processing Record 23 of Set 10 | mrirt
# City not found. Skipping ...
# Processing Record 24 of Set 10 | alice springs
# Processing Record 25 of Set 10 | mirina
# City not found. Skipping ...
# Processing Record 26 of Set 10 | manaure
# Processing Record 27 of Set 10 | casa nova
# Processing Record 28 of Set 10 | cartagena
# Processing Record 29 of Set 10 | macon
# Processing Record 30 of Set 10 | matagami
# Processing Record 31 of Set 10 | mackenzie
# Processing Record 32 of Set 10 | sakakah
# Processing Record 33 of Set 10 | farah
# Processing Record 34 of Set 10 | hede
# Processing Record 35 of Set 10 | tete
# Processing Record 36 of Set 10 | medicine hat
# Processing Record 37 of Set 10 | grosseto
# Processing Record 38 of Set 10 | bataipora
# Processing Record 39 of Set 10 | broome
# Processing Record 40 of Set 10 | smithers
# Processing Record 41 of Set 10 | almaznyy
# Processing Record 42 of Set 10 | puerto madryn
# Processing Record 43 of Set 10 | havelock
# Processing Record 44 of Set 10 | sao jose da coroa grande
# Processing Record 45 of Set 10 | cam ranh
# Processing Record 46 of Set 10 | belmonte
# Processing Record 47 of Set 10 | mackay
# Processing Record 48 of Set 10 | sumbawa
# City not found. Skipping ...
# Processing Record 49 of Set 10 | talawdi
# City not found. Skipping ...
# Processing Record 50 of Set 10 | satun
# Processing Record 1 of Set 11 | peleduy
# Processing Record 2 of Set 11 | mumford
# Processing Record 3 of Set 11 | flinders
# Processing Record 4 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping ...
# Processing Record 5 of Set 11 | galesong
# Processing Record 6 of Set 11 | marfino
# Processing Record 7 of Set 11 | archidona
# Processing Record 8 of Set 11 | emerald
# Processing Record 9 of Set 11 | qostanay
# Processing Record 10 of Set 11 | chara
# Processing Record 11 of Set 11 | auki
# Processing Record 12 of Set 11 | sosnovskiy
# City not found. Skipping ...
# Processing Record 13 of Set 11 | asfi
# Processing Record 14 of Set 11 | saint simons
# Processing Record 15 of Set 11 | cetraro
# Processing Record 16 of Set 11 | loule
# Processing Record 17 of Set 11 | invermere
# Processing Record 18 of Set 11 | nuuk
# Processing Record 19 of Set 11 | korgen
# Processing Record 20 of Set 11 | minden
# Processing Record 21 of Set 11 | saint-augustin
# Processing Record 22 of Set 11 | mergui
# City not found. Skipping ...
# Processing Record 23 of Set 11 | olafsvik
# Processing Record 24 of Set 11 | labuhan
# Processing Record 25 of Set 11 | magdagachi
# Processing Record 26 of Set 11 | atar
# Processing Record 27 of Set 11 | balaguer
# Processing Record 28 of Set 11 | hailar
# Processing Record 29 of Set 11 | manoel urbano
# Processing Record 30 of Set 11 | tahe
# Processing Record 31 of Set 11 | kunya
# Processing Record 32 of Set 11 | mount isa
# Processing Record 33 of Set 11 | palmer
# Processing Record 34 of Set 11 | tanete
# Processing Record 35 of Set 11 | margate
# Processing Record 36 of Set 11 | saint-denis
# Processing Record 37 of Set 11 | marevo
# Processing Record 38 of Set 11 | asau
# Processing Record 39 of Set 11 | saint stephen
# Processing Record 40 of Set 11 | antequera
# Processing Record 41 of Set 11 | srednekolymsk
# Processing Record 42 of Set 11 | karaton
# Processing Record 43 of Set 11 | mecca
# Processing Record 44 of Set 11 | yining
# Processing Record 45 of Set 11 | anar darreh
# City not found. Skipping ...
# Processing Record 46 of Set 11 | mae hong son
# Processing Record 47 of Set 11 | makakilo city
# Processing Record 48 of Set 11 | bihoro
# Processing Record 49 of Set 11 | floresta
# Processing Record 50 of Set 11 | taclobo
# Processing Record 1 of Set 12 | san patricio
# Processing Record 2 of Set 12 | uppsala
# Processing Record 3 of Set 12 | nieuw nickerie
# Processing Record 4 of Set 12 | ugento
# Processing Record 5 of Set 12 | derzhavinsk
# Processing Record 6 of Set 12 | kilcock
# Processing Record 7 of Set 12 | buochs
# Processing Record 8 of Set 12 | utiroa
# City not found. Skipping ...
# Processing Record 9 of Set 12 | fairlie
# {'City': ['Saint-Philippe',
#   'Punta Arenas',
#   'Nānākuli',
#   'Mahébourg',
#   'Kuruman',
#   'Cidreira',
#   'Yellowknife',
#   'Nikolskoye',
#   'Rikitea',
#   'Shīeli',
#   'Norman Wells',
#   'Ambovombe',
#   'Bilibino',
#   'Faya',
#   'Mataura',
#   'Salaga',
#   'Daru',
#   'Half Moon Bay',
#   'Jamestown',
#   'Te Anau',
#   'São Filipe',
#   'Carnarvon',
#   'Kirkwall',
#   'Neuquén',
#   'Pitsunda',
#   'Tuktoyaktuk',
#   'Copalillo',
#   'Ucluelet',
#   'Busselton',
#   'Hermanus',
#   'Lodwar',
#   'Murdochville',
#   'Bethel',
#   'Nanortalik',
#   'Port Elizabeth',
#   'Río Gallegos',
#   "Nikol'sk",
#   'Kapaa',
#   "Severo-Kuril'sk",
#   'Klaksvík',
#   'Saskylakh',
#   'Upernavik',
#   'Malakal',
#   'East London',
#   'George Town',
#   'Bredasdorp',
#   'Along',
#   'Saint-Pierre',
#   'Albany',
#   'Tyup',
#   'Butaritari',
#   'Quesnel',
#   'Cabo San Lucas',
#   'Puerto Ayora',
#   'Buta',
#   'Haines Junction',
#   'Cherskiy',
#   'Santa Cruz',
#   'Cape Town',
#   'Bekhtery',
#   'Grindavik',
#   'Daoukro',
#   'College',
#   'Sibu',
#   'Bengkulu',
#   'Ushuaia',
#   'Puerto Colombia',
#   'Qaanaaq',
#   'Kango',
#   'Lavrentiya',
#   'Mariehamn',
#   'Maricá',
#   'Salinas',
#   'Adrar',
#   'Chupa',
#   'Byron Bay',
#   'Vaini',
#   'Asunción Nochixtlán',
#   'Khatanga',
#   'Vianópolis',
#   'Camaná',
#   'Sungai Penuh',
#   'Rome',
#   'Constitución',
#   'Itoman',
#   'Guerrero Negro',
#   'Gubkinskiy',
#   'Bluff',
#   'Cockburn Town',
#   'Gorin',
#   'Uyuni',
#   'Viranşehir',
#   'Kirakira',
#   'Portland',
#   'São Raimundo Nonato',
#   'Airai',
#   'Ngunguru',
#   'Hilo',
#   'Itarema',
#   'Chokurdakh',
#   'Pevek',
#   'Ziarat',
#   'Ribeira Grande',
#   'Kendal',
#   'Grandview',
#   'Chodavaram',
#   'La Asuncion',
#   'Saint George',
#   'Mujiayingzi',
#   'Sitka',
#   'Narsaq',
#   'Port Alfred',
#   'Khovd',
#   'Abhā',
#   'Muhos',
#   'Hithadhoo',
#   'Pisco',
#   'Kyshtovka',
#   'Binzhou',
#   'Hoshcha',
#   'Avarua',
#   'Yulara',
#   'Lebu',
#   'Shanhecun',
#   'Vardø',
#   'Lorengau',
#   'Nemuro',
#   'Qaqortoq',
#   'Conceição do Araguaia',
#   'Manta',
#   'Amstetten',
#   'Verkhnyaya Inta',
#   'Inverell',
#   'Talnakh',
#   'Tiquicheo',
#   'Tela',
#   'Hobart',
#   'Bambous Virieux',
#   'Ponta do Sol',
#   'Esperance',
#   'Tasiilaq',
#   'Avera',
#   'Chui',
#   'Hong Kong',
#   'Muli',
#   'Takoradze',
#   'Tommot',
#   'Maragogi',
#   'Padang',
#   'Bonavista',
#   'Qui Nhon',
#   'Tazovsky',
#   'Port Lincoln',
#   'Baykit',
#   'Faanui',
#   'New Norfolk',
#   'Mehamn',
#   'Dikson',
#   'Motygino',
#   'Kavieng',
#   'Fairbanks',
#   'Vilyuysk',
#   "Krasnosel'kup",
#   'Mollendo',
#   'Saint Paul Harbor',
#   'Grand Gaube',
#   'Acaraú',
#   'Marabu',
#   'Gemeente Enkhuizen',
#   'Tuatapere',
#   'Jiwani',
#   'Bathsheba',
#   'Churapcha',
#   'Santa Maria',
#   'Ulaangom',
#   'Barrow',
#   'Vestmannaeyjar',
#   'Opuwo',
#   'Vila Franca do Campo',
#   'Moose Factory',
#   'Olinda',
#   'Roald',
#   'Caraballeda',
#   'Aklavik',
#   'Benxi',
#   'Udachny',
#   "Mil'kovo",
#   'Samarai',
#   'Mar del Plata',
#   'Sangar',
#   'Cavalcante',
#   'Hofn',
#   'Torbay',
#   'Kalmunai',
#   'Nome',
#   'Atuona',
#   'Anadyr',
#   'Boden',
#   'Waipawa',
#   'Salalah',
#   'Gao',
#   'Bandarbeyla',
#   'Isangel',
#   'Hammerfest',
#   'Talakan',
#   'Naze',
#   'Bani Walid',
#   'Macapá',
#   'Dingle',
#   'Laas',
#   "Tyul'gan",
#   'Thompson',
#   'Donskoy',
#   'Soavinandriana',
#   'Krasnyy Yar',
#   'North Bend',
#   'Jalu',
#   'Provideniya',
#   'Benguela',
#   'Vostok',
#   'Ayan',
#   'Eyl',
#   'Pilar',
#   'Lamesa',
#   'Lata',
#   'Tricase',
#   'Hualmay',
#   'Portree',
#   'Kruisfontein',
#   'Tres Arroyos',
#   'Acapulco de Juárez',
#   'Mananara',
#   'La Rioja',
#   'Luleå',
#   'Russell',
#   'Isla Vista',
#   'Kasempa',
#   'Ilulissat',
#   'Galle',
#   'Tumpat',
#   'Fortuna',
#   'Mayo',
#   'Taoudenni',
#   'Chato',
#   'São Sepé',
#   'Rawson',
#   'Biak',
#   'Ostrovnoy',
#   'Mount Gambier',
#   'Baturinskaya',
#   'Hasaki',
#   'Vestmanna',
#   'Bariloche',
#   'Westport',
#   'Newton',
#   'Maki',
#   'Sittwe',
#   'Dubbo',
#   'Yangi Marg`ilon',
#   'Aykhal',
#   'Talaya',
#   'Iquique',
#   'Arraial do Cabo',
#   'Tiksi',
#   'Lüderitz',
#   'Raudeberg',
#   'Belyy Yar',
#   'Pangnirtung',
#   'Kumul',
#   'Coihueco',
#   'Codrington',
#   'Castro',
#   'Lillehammer',
#   'Semey',
#   'Bismarck',
#   'Mūdbidri',
#   'Port Blair',
#   'Polovinnoye',
#   'Longyearbyen',
#   'São João da Barra',
#   'Hayden',
#   'Bruneck',
#   'Souillac',
#   'Menongue',
#   'Gornopravdinsk',
#   'Erdenet',
#   'Cayenne',
#   'Sarangani',
#   'Bilma',
#   'Geraldton',
#   'Båtsfjord',
#   'Carutapera',
#   'Leningradskiy',
#   'Kununurra',
#   'Berbera',
#   'Zhigansk',
#   'Ahipara',
#   'Searcy',
#   'Shaoyang',
#   'Keflavik',
#   'Whitecourt',
#   'Natal',
#   'Shuyskoye',
#   'Batagay-Alyta',
#   'Huarmey',
#   'Negombo',
#   'Pingshan',
#   'Adré',
#   'Buraidah',
#   'Bintulu',
#   'Lagoa',
#   'Kinablangan',
#   'Nizwá',
#   'Bamako',
#   'Ciudad Guayana',
#   'Pochutla',
#   'Majene',
#   'Husavik',
#   'Pavlikeni',
#   'Petrove',
#   'Walvis Bay',
#   'Beringovskiy',
#   'Los Llanos de Aridane',
#   'Deputatsky',
#   'Corsicana',
#   'Banda Aceh',
#   'Santa Cruz de la Sierra',
#   'Shirgaon',
#   'Puerto Limón',
#   'Barranca',
#   'Nagato',
#   'Tessalit',
#   'Sioux Lookout',
#   'Nishifukuma',
#   'Praia',
#   'Marzuq',
#   'Sørland',
#   'Eilat',
#   'Katsuura',
#   'Rio Grande',
#   'Benicarló',
#   'Marsá Maţrūḩ',
#   'Alofi',
#   'Funtua',
#   'Shangrao',
#   'Okhotsk',
#   'Oyón',
#   'Finschhafen',
#   'Dudinka',
#   'University Place',
#   'Coyhaique',
#   'Dutse',
#   'Meadow Lake',
#   'At-Bashi',
#   'Paragominas',
#   'Vila',
#   'Kizema',
#   'Turukhansk',
#   'Rosita',
#   'Paraty',
#   'Terrace',
#   'Buala',
#   'Bairiki Village',
#   'City of San Pedro',
#   'Sarkand',
#   'Tiznit Province',
#   'West Odessa',
#   'Euclides da Cunha',
#   'Iqaluit',
#   'Ipixuna',
#   'Valpaços',
#   'Mamakan',
#   'Maceió',
#   'Nangomba',
#   'Cabedelo',
#   'Riachão das Neves',
#   'Saldanha',
#   'Ketchikan',
#   'Kaitangata',
#   'Mairana',
#   'Coquimbo',
#   'Yinchuan',
#   'Fort Nelson',
#   'Manakara',
#   'Ryōtsu-minato',
#   'Arrondissement de Niort',
#   'Yar-Sale',
#   'Vila Velha',
#   'Sola',
#   'Valdivia',
#   'Aracati',
#   'Riyadh',
#   'São Félix do Xingu',
#   'Chernyshevskiy',
#   'Elliot',
#   'Salekhard',
#   'Ambon City',
#   'San Quintín',
#   'Novokuznetsk',
#   'Mahon',
#   'Omsukchan',
#   'Comodoro Rivadavia',
#   'Petropavlovsk-Kamchatskiy',
#   'Malanville',
#   'San Vicente',
#   'Sajanan',
#   'Jinchang',
#   'Clyde River',
#   'Nadym',
#   'Batemans Bay',
#   "Kolyvan'",
#   'Kamaishi',
#   'Ban Dung',
#   'Bolobo',
#   'Thanh Hoa',
#   'Betafo',
#   'Poum',
#   'Bestöbe',
#   'Miraflores',
#   'Roebourne',
#   'Pascagoula',
#   'Marshall',
#   'Jombang',
#   'Karratha',
#   'Kahului',
#   'Lompoc',
#   'Bembèrèkè',
#   'Namatanai',
#   'Kushtagi',
#   'Oranjemund',
#   'Kobryn',
#   'Lundazi',
#   'Westerland',
#   'Sampit',
#   'Chabahar',
#   'Darnah',
#   'Wattegama',
#   'Maltahöhe',
#   'Manzhouli',
#   'Lālmohan',
#   'Māngrol',
#   'San Cristobal',
#   'Gravelbourg',
#   'Phan Thiet',
#   'Conway',
#   'Maniitsoq',
#   'Sandovo',
#   'Wajima',
#   'Sorong',
#   'Korla',
#   'Narrabri',
#   'Funadhoo',
#   'Arujá',
#   'Shirokiy',
#   'Stolin',
#   'Xifeng',
#   'Takelsa',
#   'Dodge City',
#   'Richards Bay',
#   'Arlit',
#   'South Sioux City',
#   'Calamar',
#   'Andenes',
#   'Barra Patuca',
#   'Ternate',
#   'Bucerías',
#   'Melendugno',
#   'Semīrom',
#   'Caravelas',
#   'La Ronge',
#   'Laguna',
#   'Hamilton',
#   'Brønnøysund',
#   'Antananarivo',
#   'Ancud',
#   'Kamenka',
#   'Alice Springs',
#   'Manaure',
#   'Casa Nova',
#   'Cartagena',
#   'Macon',
#   'Matagami',
#   'Mackenzie',
#   'Sakakah',
#   'Farah',
#   'Hede',
#   'Tete',
#   'Medicine Hat',
#   'Provincia di Grosseto',
#   'Bataiporã',
#   'Broome',
#   'Smithers',
#   'Almaznyy',
#   'Puerto Madryn',
#   'Havelock',
#   'São José da Coroa Grande',
#   'Cam Ranh',
#   'Belmonte',
#   'Mackay',
#   'Satun',
#   'Peleduy',
#   'Mumford',
#   'Flinders',
#   'Galesong',
#   'Marfino',
#   'Archidona',
#   'Emerald',
#   'Kostanay',
#   'Chara',
#   'Auki',
#   'Safi',
#   'Saint Simons',
#   'Cetraro',
#   'Loulé',
#   'Invermere',
#   'Nuuk',
#   'Korgen',
#   'Minden',
#   'Saint-Augustin',
#   'Olafsvik',
#   'Labuhan',
#   'Magdagachi',
#   'Atar',
#   'Balaguer',
#   'Hailar',
#   'Manoel Urbano',
#   'Tahe',
#   'Kunya',
#   'Mount Isa',
#   'Palmer',
#   'Tanete',
#   'Margate',
#   'Arrondissement de Saint-Denis',
#   'Marevo',
#   'Asău',
#   'Saint Stephen',
#   'Antequera',
#   'Srednekolymsk',
#   'Karaton',
#   'Makkah al Mukarramah',
#   'Yining',
#   'Mae Hong Son',
#   'Makakilo City',
#   'Motomachi',
#   'Floresta',
#   'Taclobo',
#   'San Patricio',
#   'Uppsala County',
#   'Nieuw Nickerie',
#   'Ugento',
#   'Derzhavīnsk',
#   'Kilcock',
#   'Buochs',
#   'Fairlie'],
#  'Cloudiness': [75,
#   75,
#   90,
#   75,
#   0,
#   43,
#   90,
#   99,
#   85,
#   100,
#   90,
#   0,
#   40,
#   0,
#   46,
#   100,
#   100,
#   75,
#   90,
#   18,
#   0,
#   0,
#   65,
#   20,
#   90,
#   90,
#   0,
#   100,
#   0,
#   100,
#   100,
#   100,
#   90,
#   83,
#   75,
#   100,
#   100,
#   75,
#   100,
#   100,
#   0,
#   64,
#   69,
#   37,
#   40,
#   100,
#   100,
#   75,
#   75,
#   7,
#   30,
#   90,
#   90,
#   2,
#   65,
#   100,
#   100,
#   0,
#   100,
#   90,
#   75,
#   100,
#   1,
#   75,
#   0,
#   40,
#   62,
#   0,
#   88,
#   91,
#   90,
#   0,
#   90,
#   0,
#   100,
#   75,
#   75,
#   32,
#   25,
#   2,
#   51,
#   0,
#   90,
#   73,
#   75,
#   100,
#   100,
#   49,
#   32,
#   100,
#   20,
#   100,
#   100,
#   1,
#   59,
#   44,
#   95,
#   90,
#   100,
#   64,
#   32,
#   89,
#   100,
#   29,
#   1,
#   20,
#   90,
#   1,
#   54,
#   75,
#   94,
#   100,
#   100,
#   0,
#   90,
#   100,
#   20,
#   64,
#   0,
#   100,
#   43,
#   90,
#   100,
#   30,
#   100,
#   24,
#   20,
#   23,
#   40,
#   40,
#   75,
#   100,
#   81,
#   75,
#   0,
#   75,
#   20,
#   75,
#   20,
#   40,
#   20,
#   90,
#   0,
#   40,
#   100,
#   92,
#   100,
#   39,
#   33,
#   100,
#   51,
#   100,
#   48,
#   100,
#   47,
#   20,
#   100,
#   100,
#   100,
#   90,
#   1,
#   100,
#   100,
#   43,
#   1,
#   75,
#   100,
#   75,
#   90,
#   31,
#   0,
#   20,
#   98,
#   100,
#   70,
#   1,
#   100,
#   0,
#   75,
#   1,
#   40,
#   67,
#   91,
#   90,
#   0,
#   0,
#   100,
#   95,
#   50,
#   100,
#   100,
#   100,
#   90,
#   41,
#   90,
#   1,
#   98,
#   100,
#   100,
#   9,
#   100,
#   15,
#   75,
#   75,
#   0,
#   75,
#   48,
#   75,
#   27,
#   75,
#   97,
#   20,
#   86,
#   0,
#   98,
#   1,
#   67,
#   2,
#   100,
#   100,
#   100,
#   0,
#   20,
#   90,
#   90,
#   40,
#   0,
#   98,
#   28,
#   0,
#   40,
#   96,
#   0,
#   100,
#   40,
#   90,
#   100,
#   100,
#   1,
#   20,
#   0,
#   90,
#   0,
#   100,
#   31,
#   100,
#   55,
#   99,
#   76,
#   0,
#   20,
#   100,
#   20,
#   90,
#   90,
#   75,
#   96,
#   0,
#   100,
#   0,
#   50,
#   69,
#   24,
#   23,
#   100,
#   100,
#   40,
#   22,
#   100,
#   42,
#   5,
#   0,
#   100,
#   20,
#   1,
#   11,
#   53,
#   52,
#   40,
#   1,
#   90,
#   75,
#   75,
#   100,
#   100,
#   94,
#   24,
#   0,
#   15,
#   0,
#   100,
#   100,
#   49,
#   0,
#   40,
#   0,
#   57,
#   1,
#   92,
#   75,
#   75,
#   40,
#   100,
#   29,
#   0,
#   40,
#   21,
#   50,
#   0,
#   75,
#   100,
#   100,
#   0,
#   100,
#   0,
#   0,
#   82,
#   90,
#   90,
#   90,
#   0,
#   100,
#   100,
#   77,
#   1,
#   85,
#   40,
#   40,
#   0,
#   0,
#   40,
#   90,
#   20,
#   40,
#   0,
#   0,
#   100,
#   76,
#   20,
#   77,
#   0,
#   24,
#   75,
#   21,
#   0,
#   92,
#   15,
#   99,
#   75,
#   40,
#   90,
#   36,
#   75,
#   92,
#   100,
#   90,
#   100,
#   100,
#   66,
#   27,
#   75,
#   100,
#   75,
#   75,
#   100,
#   0,
#   1,
#   99,
#   5,
#   75,
#   0,
#   22,
#   20,
#   100,
#   20,
#   96,
#   100,
#   90,
#   67,
#   18,
#   90,
#   0,
#   90,
#   67,
#   75,
#   90,
#   100,
#   40,
#   43,
#   90,
#   100,
#   0,
#   93,
#   0,
#   15,
#   100,
#   20,
#   100,
#   86,
#   39,
#   13,
#   40,
#   90,
#   100,
#   0,
#   40,
#   36,
#   40,
#   100,
#   55,
#   48,
#   75,
#   85,
#   99,
#   94,
#   51,
#   0,
#   0,
#   75,
#   0,
#   90,
#   1,
#   16,
#   11,
#   40,
#   90,
#   30,
#   100,
#   58,
#   99,
#   100,
#   88,
#   52,
#   38,
#   0,
#   100,
#   20,
#   0,
#   97,
#   0,
#   25,
#   75,
#   68,
#   87,
#   1,
#   11,
#   92,
#   75,
#   100,
#   0,
#   90,
#   51,
#   40,
#   0,
#   100,
#   9,
#   40,
#   1,
#   64,
#   40,
#   90,
#   40,
#   100,
#   1,
#   5,
#   75,
#   49,
#   0,
#   100,
#   90,
#   20,
#   90,
#   100,
#   40,
#   40,
#   59,
#   0,
#   99,
#   75,
#   40,
#   90,
#   1,
#   75,
#   65,
#   0,
#   0,
#   50,
#   75,
#   55,
#   0,
#   90,
#   75,
#   9,
#   100,
#   90,
#   39,
#   20,
#   75,
#   90,
#   40,
#   82,
#   100,
#   40,
#   20,
#   75,
#   32,
#   87,
#   90,
#   100,
#   87,
#   0,
#   1,
#   11,
#   0,
#   99,
#   20,
#   90,
#   40,
#   100,
#   100,
#   100,
#   100,
#   0,
#   0,
#   100,
#   29,
#   97,
#   96,
#   10,
#   90,
#   78,
#   100,
#   90,
#   100,
#   33,
#   95,
#   32,
#   100,
#   40,
#   0,
#   98,
#   20,
#   90,
#   40,
#   49,
#   0,
#   40,
#   100,
#   31,
#   40,
#   100,
#   40,
#   75,
#   20],
#  'Country': ['RE',
#   'CL',
#   'US',
#   'MU',
#   'ZA',
#   'BR',
#   'CA',
#   'RU',
#   'PF',
#   'KZ',
#   'CA',
#   'MG',
#   'RU',
#   'SA',
#   'NZ',
#   'GH',
#   'PG',
#   'US',
#   'US',
#   'NZ',
#   'CV',
#   'AU',
#   'GB',
#   'AR',
#   'GE',
#   'CA',
#   'MX',
#   'CA',
#   'AU',
#   'ZA',
#   'KE',
#   'CA',
#   'US',
#   'GL',
#   'ZA',
#   'AR',
#   'RU',
#   'US',
#   'RU',
#   'FO',
#   'RU',
#   'GL',
#   'SS',
#   'ZA',
#   'MY',
#   'ZA',
#   'IN',
#   'RE',
#   'US',
#   'KG',
#   'KI',
#   'CA',
#   'MX',
#   'EC',
#   'CD',
#   'CA',
#   'RU',
#   'MA',
#   'ZA',
#   'UA',
#   'IS',
#   'CI',
#   'US',
#   'MY',
#   'ID',
#   'AR',
#   'CO',
#   'GL',
#   'GA',
#   'RU',
#   'AX',
#   'BR',
#   'US',
#   'MR',
#   'RU',
#   'AU',
#   'TO',
#   'MX',
#   'RU',
#   'BR',
#   'PE',
#   'ID',
#   'US',
#   'CL',
#   'JP',
#   'MX',
#   'RU',
#   'NZ',
#   'TC',
#   'RU',
#   'BO',
#   'TR',
#   'SB',
#   'US',
#   'BR',
#   'TL',
#   'NZ',
#   'US',
#   'BR',
#   'RU',
#   'RU',
#   'PK',
#   'PT',
#   'GB',
#   'US',
#   'IN',
#   'VE',
#   'US',
#   'CN',
#   'US',
#   'GL',
#   'ZA',
#   'MN',
#   'SA',
#   'FI',
#   'MV',
#   'PE',
#   'RU',
#   'CN',
#   'UA',
#   'CK',
#   'AU',
#   'CL',
#   'CN',
#   'NO',
#   'PG',
#   'JP',
#   'GL',
#   'BR',
#   'EC',
#   'AT',
#   'RU',
#   'AU',
#   'RU',
#   'MX',
#   'HN',
#   'AU',
#   'MU',
#   'PT',
#   'AU',
#   'GL',
#   'US',
#   'UY',
#   'HK',
#   'MV',
#   'GH',
#   'RU',
#   'BR',
#   'ID',
#   'CA',
#   'VN',
#   'RU',
#   'AU',
#   'RU',
#   'PF',
#   'AU',
#   'NO',
#   'RU',
#   'RU',
#   'PG',
#   'US',
#   'RU',
#   'RU',
#   'PE',
#   'US',
#   'MU',
#   'BR',
#   'MY',
#   'NL',
#   'NZ',
#   'PK',
#   'BB',
#   'RU',
#   'BR',
#   'MN',
#   'US',
#   'IS',
#   'NA',
#   'PT',
#   'CA',
#   'BR',
#   'NO',
#   'VE',
#   'CA',
#   'CN',
#   'RU',
#   'RU',
#   'PG',
#   'AR',
#   'RU',
#   'BR',
#   'IS',
#   'CA',
#   'LK',
#   'US',
#   'PF',
#   'RU',
#   'SE',
#   'NZ',
#   'OM',
#   'ML',
#   'SO',
#   'VU',
#   'NO',
#   'RU',
#   'JP',
#   'LY',
#   'BR',
#   'PH',
#   'IT',
#   'RU',
#   'CA',
#   'RU',
#   'MG',
#   'RU',
#   'US',
#   'LY',
#   'RU',
#   'AO',
#   'RU',
#   'RU',
#   'SO',
#   'BR',
#   'US',
#   'PT',
#   'IT',
#   'PE',
#   'GB',
#   'ZA',
#   'AR',
#   'MX',
#   'MG',
#   'ES',
#   'SE',
#   'US',
#   'US',
#   'ZM',
#   'GL',
#   'LK',
#   'MY',
#   'US',
#   'US',
#   'ML',
#   'TZ',
#   'BR',
#   'AR',
#   'ID',
#   'RU',
#   'AU',
#   'RU',
#   'JP',
#   'FO',
#   'AR',
#   'US',
#   'US',
#   'JP',
#   'MM',
#   'AU',
#   'UZ',
#   'RU',
#   'RU',
#   'CL',
#   'BR',
#   'RU',
#   'NA',
#   'NO',
#   'RU',
#   'CA',
#   'CN',
#   'CL',
#   'AU',
#   'BR',
#   'NO',
#   'KZ',
#   'US',
#   'IN',
#   'IN',
#   'RU',
#   'SJ',
#   'BR',
#   'US',
#   'IT',
#   'MU',
#   'AO',
#   'RU',
#   'MN',
#   'GF',
#   'PH',
#   'NE',
#   'AU',
#   'NO',
#   'BR',
#   'RU',
#   'AU',
#   'SO',
#   'RU',
#   'NZ',
#   'US',
#   'CN',
#   'IS',
#   'CA',
#   'BR',
#   'RU',
#   'RU',
#   'PE',
#   'LK',
#   'CN',
#   'TD',
#   'SA',
#   'MY',
#   'PT',
#   'PH',
#   'OM',
#   'ML',
#   'VE',
#   'MX',
#   'ID',
#   'IS',
#   'BG',
#   'UA',
#   'NA',
#   'RU',
#   'ES',
#   'RU',
#   'US',
#   'ID',
#   'BO',
#   'IN',
#   'CR',
#   'PE',
#   'JP',
#   'ML',
#   'CA',
#   'JP',
#   'CV',
#   'YE',
#   'NO',
#   'IL',
#   'JP',
#   'BR',
#   'ES',
#   'EG',
#   'NU',
#   'NG',
#   'CN',
#   'RU',
#   'PE',
#   'PG',
#   'RU',
#   'US',
#   'CL',
#   'NG',
#   'US',
#   'KG',
#   'BR',
#   'PT',
#   'RU',
#   'RU',
#   'NI',
#   'BR',
#   'CA',
#   'SB',
#   'KI',
#   'PH',
#   'KZ',
#   'MA',
#   'US',
#   'BR',
#   'CA',
#   'BR',
#   'PT',
#   'RU',
#   'BR',
#   'TZ',
#   'BR',
#   'BR',
#   'ZA',
#   'US',
#   'NZ',
#   'BO',
#   'CL',
#   'CN',
#   'CA',
#   'MG',
#   'JP',
#   'FR',
#   'RU',
#   'BR',
#   'VU',
#   'CL',
#   'BR',
#   'SA',
#   'BR',
#   'RU',
#   'ZA',
#   'RU',
#   'ID',
#   'MX',
#   'RU',
#   'ES',
#   'RU',
#   'AR',
#   'RU',
#   'BJ',
#   'AR',
#   'TN',
#   'CN',
#   'CA',
#   'RU',
#   'AU',
#   'RU',
#   'JP',
#   'TH',
#   'CD',
#   'VN',
#   'MG',
#   'NC',
#   'KZ',
#   'MX',
#   'AU',
#   'US',
#   'US',
#   'ID',
#   'AU',
#   'US',
#   'US',
#   'BJ',
#   'PG',
#   'IN',
#   'NA',
#   'BY',
#   'ZM',
#   'DE',
#   'ID',
#   'IR',
#   'LY',
#   'LK',
#   'NA',
#   'CN',
#   'BD',
#   'IN',
#   'VE',
#   'CA',
#   'VN',
#   'US',
#   'GL',
#   'RU',
#   'JP',
#   'ID',
#   'CN',
#   'AU',
#   'MV',
#   'BR',
#   'RU',
#   'BY',
#   'CN',
#   'TN',
#   'US',
#   'ZA',
#   'NE',
#   'US',
#   'CO',
#   'NO',
#   'HN',
#   'ID',
#   'MX',
#   'IT',
#   'IR',
#   'BR',
#   'CA',
#   'US',
#   'US',
#   'NO',
#   'MG',
#   'CL',
#   'RU',
#   'AU',
#   'CO',
#   'BR',
#   'CO',
#   'US',
#   'CA',
#   'CA',
#   'SA',
#   'AF',
#   'CN',
#   'MZ',
#   'CA',
#   'IT',
#   'BR',
#   'US',
#   'CA',
#   'RU',
#   'AR',
#   'US',
#   'BR',
#   'VN',
#   'BR',
#   'AU',
#   'TH',
#   'RU',
#   'GH',
#   'AU',
#   'ID',
#   'RU',
#   'ES',
#   'AU',
#   'KZ',
#   'RU',
#   'SB',
#   'MA',
#   'US',
#   'IT',
#   'PT',
#   'CA',
#   'GL',
#   'NO',
#   'DE',
#   'CA',
#   'IS',
#   'ID',
#   'RU',
#   'MR',
#   'ES',
#   'CN',
#   'BR',
#   'CN',
#   'NG',
#   'AU',
#   'US',
#   'ID',
#   'GB',
#   'FR',
#   'RU',
#   'RO',
#   'GB',
#   'ES',
#   'RU',
#   'ID',
#   'SA',
#   'CN',
#   'TH',
#   'US',
#   'JP',
#   'BR',
#   'PH',
#   'MX',
#   'SE',
#   'SR',
#   'IT',
#   'KZ',
#   'IE',
#   'CH',
#   'GB'],
#  'Date': [1583896216,
#   1583896216,
#   1583896216,
#   1583896216,
#   1583896216,
#   1583896216,
#   1583896216,
#   1583896216,
#   1583896216,
#   1583895997,
#   1583896216,
#   1583896216,
#   1583896216,
#   1583896217,
#   1583896217,
#   1583896217,
#   1583896217,
#   1583896217,
#   1583895990,
#   1583896217,
#   1583896217,
#   1583896217,
#   1583896217,
#   1583896218,
#   1583896218,
#   1583896218,
#   1583896218,
#   1583896149,
#   1583895933,
#   1583896218,
#   1583896218,
#   1583896218,
#   1583896218,
#   1583896218,
#   1583896218,
#   1583896218,
#   1583895972,
#   1583896218,
#   1583896219,
#   1583896219,
#   1583896219,
#   1583896106,
#   1583896219,
#   1583896219,
#   1583895922,
#   1583896219,
#   1583896025,
#   1583896219,
#   1583896219,
#   1583896219,
#   1583896219,
#   1583896097,
#   1583895943,
#   1583896220,
#   1583896220,
#   1583896220,
#   1583896220,
#   1583896220,
#   1583895977,
#   1583896220,
#   1583896220,
#   1583896220,
#   1583896221,
#   1583896221,
#   1583896099,
#   1583896163,
#   1583896221,
#   1583896221,
#   1583896221,
#   1583896221,
#   1583896221,
#   1583896221,
#   1583896221,
#   1583896221,
#   1583896221,
#   1583896221,
#   1583896222,
#   1583896222,
#   1583896222,
#   1583896222,
#   1583896222,
#   1583896222,
#   1583896222,
#   1583896222,
#   1583896222,
#   1583896222,
#   1583896222,
#   1583896222,
#   1583896198,
#   1583896222,
#   1583896222,
#   1583896222,
#   1583896223,
#   1583896074,
#   1583896223,
#   1583896223,
#   1583896223,
#   1583896223,
#   1583896223,
#   1583896223,
#   1583896223,
#   1583896223,
#   1583896223,
#   1583896223,
#   1583896223,
#   1583896224,
#   1583896224,
#   1583896224,
#   1583896224,
#   1583896224,
#   1583896224,
#   1583896224,
#   1583896224,
#   1583896224,
#   1583896224,
#   1583896224,
#   1583896224,
#   1583896225,
#   1583896225,
#   1583896225,
#   1583896025,
#   1583896225,
#   1583896225,
#   1583896225,
#   1583896225,
#   1583896225,
#   1583896070,
#   1583896225,
#   1583896225,
#   1583896118,
#   1583896225,
#   1583896225,
#   1583896226,
#   1583896226,
#   1583896226,
#   1583896226,
#   1583896226,
#   1583896226,
#   1583896226,
#   1583896226,
#   1583896226,
#   1583896226,
#   1583896226,
#   1583896007,
#   1583896226,
#   1583896226,
#   1583896227,
#   1583896150,
#   1583896227,
#   1583896227,
#   1583896227,
#   1583896227,
#   1583896003,
#   1583896227,
#   1583896227,
#   1583896227,
#   1583896227,
#   1583896227,
#   1583896227,
#   1583896227,
#   1583896003,
#   1583896228,
#   1583896228,
#   1583896228,
#   1583896228,
#   1583896228,
#   1583896062,
#   1583896228,
#   1583896228,
#   1583896228,
#   1583896228,
#   1583896228,
#   1583896228,
#   1583896228,
#   1583896228,
#   1583896228,
#   1583896229,
#   1583896229,
#   1583896229,
#   1583896229,
#   1583896229,
#   1583896229,
#   1583896229,
#   1583896229,
#   1583896229,
#   1583896229,
#   1583896229,
#   1583896229,
#   1583896229,
#   1583896229,
#   1583896229,
#   1583896230,
#   1583895998,
#   1583896230,
#   1583896230,
#   1583895934,
#   1583896230,
#   1583896230,
#   1583896230,
#   1583896224,
#   1583896230,
#   1583896230,
#   1583896230,
#   1583896230,
#   1583896230,
#   1583896230,
#   1583896230,
#   1583896230,
#   1583896230,
#   1583896231,
#   1583896231,
#   1583896231,
#   1583896231,
#   1583896026,
#   1583896231,
#   1583896231,
#   1583896231,
#   1583896231,
#   1583896056,
#   1583896231,
#   1583896231,
#   1583896231,
#   1583896231,
#   1583896160,
#   1583896232,
#   1583896232,
#   1583896232,
#   1583896232,
#   1583896232,
#   1583896232,
#   1583896087,
#   1583896026,
#   1583896232,
#   1583896201,
#   1583896232,
#   1583896232,
#   1583896233,
#   1583896233,
#   1583896233,
#   1583896233,
#   1583896233,
#   1583896233,
#   1583896233,
#   1583896145,
#   1583896233,
#   1583896233,
#   1583896233,
#   1583896233,
#   1583896156,
#   1583896233,
#   1583896234,
#   1583896234,
#   1583896045,
#   1583896024,
#   1583896030,
#   1583896234,
#   1583896234,
#   1583896217,
#   1583896234,
#   1583896234,
#   1583896234,
#   1583896234,
#   1583896234,
#   1583896234,
#   1583896235,
#   1583896235,
#   1583896235,
#   1583896235,
#   1583896235,
#   1583896235,
#   1583896235,
#   1583896235,
#   1583896235,
#   1583896235,
#   1583896053,
#   1583896236,
#   1583896236,
#   1583896236,
#   1583896236,
#   1583896236,
#   1583896236,
#   1583896236,
#   1583896236,
#   1583896236,
#   1583896236,
#   1583896236,
#   1583896236,
#   1583896236,
#   1583896236,
#   1583896236,
#   1583896236,
#   1583896237,
#   1583896237,
#   1583896237,
#   1583896237,
#   1583896237,
#   1583896237,
#   1583896237,
#   1583896237,
#   1583896237,
#   1583896237,
#   1583896237,
#   1583896237,
#   1583896237,
#   1583896237,
#   1583896238,
#   1583896238,
#   1583896238,
#   1583896238,
#   1583896238,
#   1583896238,
#   1583896238,
#   1583896238,
#   1583896238,
#   1583896238,
#   1583896238,
#   1583896238,
#   1583896238,
#   1583896238,
#   1583896205,
#   1583896239,
#   1583896239,
#   1583896239,
#   1583896239,
#   1583896052,
#   1583896239,
#   1583896232,
#   1583896239,
#   1583896239,
#   1583896225,
#   1583896239,
#   1583896239,
#   1583896240,
#   1583896240,
#   1583896240,
#   1583896240,
#   1583896240,
#   1583896240,
#   1583896052,
#   1583896036,
#   1583896240,
#   1583896240,
#   1583896240,
#   1583896084,
#   1583896240,
#   1583896240,
#   1583896240,
#   1583896240,
#   1583896219,
#   1583896241,
#   1583896241,
#   1583896241,
#   1583896241,
#   1583896228,
#   1583896241,
#   1583896241,
#   1583896241,
#   1583896241,
#   1583896241,
#   1583896241,
#   1583896080,
#   1583896241,
#   1583896241,
#   1583896242,
#   1583896242,
#   1583896242,
#   1583896242,
#   1583896242,
#   1583896242,
#   1583896242,
#   1583896242,
#   1583896242,
#   1583896020,
#   1583896145,
#   1583896242,
#   1583896242,
#   1583896242,
#   1583896242,
#   1583896242,
#   1583896243,
#   1583896243,
#   1583896082,
#   1583896243,
#   1583896243,
#   1583896243,
# ...
#   32.77,
#   6.8,
#   -24.83,
#   49.6,
#   22.34,
#   21.12,
#   7.77,
#   49.88,
#   10.93,
#   35.09,
#   65.42,
#   58.46,
#   37.4,
#   -0.88,
#   41.76,
#   -30.32,
#   6.15,
#   -23.4,
#   49.76,
#   51.89,
#   42.74,
#   36.78,
#   37.75,
#   -28.78,
#   18.74,
#   42.47,
#   10.25,
#   69.31,
#   15.8,
#   0.8,
#   20.75,
#   40.27,
#   31.42,
#   -17.71,
#   55.1,
#   38.42,
#   39.18,
#   65.46,
#   -18.91,
#   -41.87,
#   51.32,
#   -23.7,
#   11.78,
#   -9.42,
#   10.4,
#   39.87,
#   49.75,
#   55.3,
#   29.97,
#   32.5,
#   33.77,
#   -16.16,
#   50.05,
#   42.83,
#   -22.3,
#   42.25,
#   54.78,
#   48.04,
#   -42.77,
#   34.88,
#   -8.9,
#   11.92,
#   -15.86,
#   -21.15,
#   6.83,
#   59.63,
#   5.26,
#   -34.58,
#   -5.32,
#   55.7,
#   37.1,
#   -23.53,
#   53.17,
#   56.91,
#   -8.77,
#   32.3,
#   31.14,
#   39.52,
#   37.14,
#   50.52,
#   64.18,
#   66.08,
#   52.28,
#   51.23,
#   64.89,
#   -6.88,
#   53.45,
#   20.52,
#   41.79,
#   49.2,
#   -8.84,
#   52.33,
#   12.22,
#   -20.73,
#   42.16,
#   -3.94,
#   51.38,
#   48.92,
#   57.31,
#   46.43,
#   50.33,
#   37.02,
#   67.45,
#   -6.34,
#   21.43,
#   29.04,
#   19.3,
#   21.35,
#   43.82,
#   -8.6,
#   12.31,
#   19.22,
#   60,
#   5.95,
#   39.93,
#   51.1,
#   53.4,
#   46.97,
#   55.76],
#  'Lng': [55.77,
#   -70.92,
#   -158.15,
#   57.7,
#   23.43,
#   -50.21,
#   -114.35,
#   30.79,
#   -134.97,
#   66.75,
#   -126.83,
#   46.08,
#   166.44,
#   42.45,
#   168.86,
#   -0.52,
#   143.21,
#   -122.43,
#   -79.24,
#   167.72,
#   -24.5,
#   113.63,
#   -2.96,
#   -68.06,
#   40.34,
#   -133.04,
#   -99.12,
#   -125.55,
#   115.33,
#   19.23,
#   35.6,
#   -65.5,
#   -73.41,
#   -45.24,
#   25.57,
#   -69.22,
#   46.07,
#   -159.32,
#   156.12,
#   -6.59,
#   114.08,
#   -56.15,
#   31.66,
#   27.91,
#   100.34,
#   20.04,
#   94.77,
#   55.48,
#   -73.97,
#   78.36,
#   172.79,
#   -122.5,
#   -109.91,
#   -90.35,
#   24.73,
#   -137.51,
#   161.3,
#   -9.6,
#   18.42,
#   32.29,
#   -22.43,
#   -3.96,
#   -147.8,
#   111.82,
#   102.27,
#   -68.3,
#   -74.95,
#   -69.36,
#   10.1,
#   -171,
#   19.93,
#   -42.82,
#   -121.66,
#   -10.07,
#   33.05,
#   153.62,
#   -175.2,
#   -97.23,
#   102.5,
#   -48.52,
#   -72.71,
#   101.38,
#   -75.46,
#   -72.42,
#   127.67,
#   -114.06,
#   76.5,
#   168.33,
#   -71.14,
#   136.67,
#   -66.83,
#   39.76,
#   161.92,
#   -122.68,
#   -42.7,
#   125.41,
#   174.5,
#   -155.09,
#   -39.92,
#   147.92,
#   170.31,
#   67.73,
#   -28.7,
#   -2.75,
#   -94.53,
#   82.95,
#   -63.86,
#   -113.58,
#   118.78,
#   -135.33,
#   -46.05,
#   26.89,
#   91.64,
#   42.51,
#   25.99,
#   73.08,
#   -76.22,
#   76.63,
#   118.02,
#   26.67,
#   -159.78,
#   130.99,
#   -73.65,
#   127.2,
#   31.11,
#   147.27,
#   145.57,
#   -46.03,
#   -49.26,
#   -80.73,
#   14.87,
#   60.31,
#   151.12,
#   88.4,
#   -100.73,
#   -87.45,
#   147.33,
#   57.76,
#   -17.1,
#   121.9,
#   -37.64,
#   -82.53,
#   -53.46,
#   114.16,
#   73.57,
#   -1.76,
#   126.29,
#   -35.22,
#   100.35,
#   -53.11,
#   109.23,
#   78.7,
#   135.87,
#   96.37,
#   -151.75,
#   147.06,
#   27.85,
#   80.55,
#   94.76,
#   150.8,
#   -147.72,
#   121.62,
#   82.47,
#   -72.01,
#   -152.41,
#   57.66,
#   -40.12,
#   114.01,
#   5.28,
#   167.68,
#   61.74,
#   -59.52,
#   132.43,
#   -53.81,
#   92.07,
#   -156.79,
#   -20.27,
#   13.84,
#   -25.43,
#   -80.61,
#   -34.86,
#   6.13,
#   -66.85,
#   -135.01,
#   123.77,
#   112.4,
#   158.62,
#   150.67,
#   -57.56,
#   127.47,
#   -47.46,
#   -15.21,
#   -52.73,
#   81.82,
#   -165.41,
#   -139.03,
#   177.48,
#   21.69,
#   175.52,
#   54.09,
#   1.64,
#   50.81,
#   169.27,
#   23.68,
#   130.37,
#   129.48,
#   13.99,
#   -51.07,
#   122.67,
#   10.7,
#   56.17,
#   -97.86,
#   38.34,
#   46.73,
#   48.35,
#   -124.22,
#   21.55,
#   -173.3,
#   13.41,
#   135.88,
#   138.17,
#   49.82,
#   -35.96,
#   -101.95,
#   -8.33,
#   18.36,
#   -77.61,
#   -6.19,
#   24.73,
#   -60.28,
#   -99.89,
#   49.77,
#   -2.5,
#   22.15,
#   -85.2,
#   -119.86,
#   25.83,
#   -51.1,
#   80.22,
#   102.17,
#   -124.16,
#   -76.51,
#   -3.98,
#   31.77,
#   -53.57,
#   -65.1,
#   122.88,
#   39.51,
#   140.77,
#   39.37,
#   140.83,
#   -7.17,
#   -71.31,
#   -73.36,
#   -71.21,
#   138.88,
#   92.9,
#   148.62,
#   71.72,
#   111.5,
#   152.75,
#   -70.14,
#   -42.03,
#   128.87,
#   15.16,
#   5.14,
#   91.39,
#   -65.71,
#   93.45,
#   -71.83,
#   141.97,
#   -50.01,
#   10.47,
#   80.23,
#   -100.78,
#   74.98,
#   92.75,
#   65.99,
#   15.64,
#   -41.05,
#   -116.79,
#   11.94,
#   57.52,
#   17.69,
#   69.9,
#   104.08,
#   -52.33,
#   125.46,
#   12.92,
#   114.6,
#   29.72,
#   -46.02,
#   178.42,
#   128.73,
#   45.01,
#   123.37,
#   173.17,
#   -91.74,
#   111.45,
#   -22.56,
#   -115.69,
#   -35.21,
#   41.03,
#   130.41,
#   -78.15,
#   79.84,
#   114.71,
#   22.2,
#   43.98,
#   113.03,
#   -27.98,
#   126.55,
#   57.53,
#   -8,
#   -62.65,
#   -96.47,
#   118.97,
#   -17.34,
#   25.32,
#   33.26,
#   14.51,
#   179.32,
#   -17.92,
#   139.9,
#   -96.47,
#   95.32,
#   -63.17,
#   72.7,
#   -83.03,
#   -77.77,
#   131.2,
#   1.01,
#   -91.92,
#   130.47,
#   -23.51,
#   46.47,
#   12.69,
#   34.95,
#   140.3,
#   -52.1,
#   0.43,
#   27.25,
#   -169.92,
#   7.31,
#   117.97,
#   143.3,
#   -76.77,
#   147.87,
#   86.18,
#   -122.55,
#   -72.07,
#   9.34,
#   -106.54,
#   75.81,
#   -47.48,
#   -8.16,
#   44.83,
#   87.98,
#   -84.4,
#   -44.71,
#   -128.6,
#   159.59,
#   172.98,
#   121.02,
#   79.92,
#   -9.5,
#   -102.5,
#   -39.02,
#   -68.51,
#   -48.8,
#   -7.31,
#   114,
#   -35.74,
#   38.5,
#   -34.83,
#   -44.91,
#   17.94,
#   -131.65,
#   169.85,
#   -63.93,
#   -71.34,
#   106.27,
#   -122.7,
#   48.02,
#   138.43,
#   -0.33,
#   70.83,
#   -40.29,
#   167.55,
#   -73.25,
#   -37.77,
#   46.72,
#   -51.99,
#   112.47,
#   27.85,
#   66.6,
#   128.18,
#   -115.95,
#   87.11,
#   4.27,
#   155.8,
#   -67.5,
#   158.65,
#   3.39,
#   -54.13,
#   9.24,
#   102.17,
#   -68.59,
#   72.52,
#   150.18,
#   82.74,
#   141.88,
#   103.26,
#   16.23,
#   105.77,
#   46.85,
#   164.02,
#   73.1,
#   -98.81,
#   117.13,
#   -88.56,
#   -86.33,
#   112.23,
#   116.85,
#   -156.47,
#   -120.46,
#   2.66,
#   152.43,
#   76.2,
#   16.43,
#   24.36,
#   33.18,
#   8.3,
#   112.95,
#   60.64,
#   22.64,
#   81.48,
#   16.98,
#   117.43,
#   90.74,
#   70.12,
#   -72.22,
#   -106.55,
#   108.1,
#   -92.44,
#   -52.9,
#   36.41,
#   136.9,
#   131.25,
#   86.15,
#   149.78,
#   73.27,
#   -46.32,
#   129.52,
#   26.85,
#   124.72,
#   10.63,
#   -100.02,
#   32.04,
#   7.39,
#   -96.41,
#   -74.91,
#   16.12,
#   -84.28,
#   127.4,
#   -105.33,
#   18.34,
#   51.57,
#   -39.25,
#   -105.28,
#   -121.42,
#   -84.53,
#   12.2,
#   47.54,
#   -73.82,
#   42.77,
#   133.88,
#   -72.44,
#   -41.13,
#   -75.51,
#   -88.97,
#   -77.63,
#   -123.17,
#   40.21,
#   62.5,
#   120.25,
#   33.59,
#   -110.67,
#   11.25,
#   -53.27,
#   -75.83,
#   -127.17,
#   40.05,
#   -65.04,
#   -76.9,
#   -35.15,
#   109.16,
#   -38.88,
#   149.2,
#   100,
#   112.74,
#   -0.76,
#   150.86,
#   119.37,
#   37.38,
#   -4.39,
#   148.17,
#   63.58,
#   118.26,
#   160.7,
#   -9.24,
#   -81.39,
#   15.94,
#   -8.02,
#   -116.04,
#   -51.72,
#   13.82,
#   8.92,
#   -58.65,
#   -23.71,
#   112.21,
#   125.8,
#   -13.05,
#   0.81,
#   119.7,
#   -69.26,
#   124.73,
#   8.53,
#   139.5,
#   -72.33,
#   119.78,
#   1.39,
#   2.33,
#   32.08,
#   26.4,
#   -4.9,
#   -4.56,
#   153.68,
#   106.1,
#   39.83,
#   114.56,
#   97.97,
#   -158.09,
#   144.1,
#   -38.57,
#   122.59,
#   -104.7,
#   17.75,
#   -56.98,
#   18.16,
#   66.32,
#   -6.67,
#   8.42,
#   -4.86],
#  'Max Temp': [300.15,
#   282.04,
#   299.15,
#   299.15,
#   288.23,
#   297.06,
#   263.15,
#   277.04,
#   298.81,
#   277.99,
#   251.15,
#   293.3,
#   252.63,
#   288.15,
#   286.48,
#   301.35,
#   306.23,
#   292.15,
#   275.37,
#   284.51,
#   295.09,
#   300.15,
#   279.26,
#   295.15,
#   286.15,
#   245.15,
#   294.48,
#   281.48,
#   303.71,
#   292.7,
#   300.8,
#   262.55,
#   288.71,
#   266.82,
#   291.15,
#   283.15,
#   274.79,
#   299.15,
#   274.08,
#   278.15,
#   244.56,
#   240.89,
#   298.46,
#   294.29,
#   301.15,
#   293.15,
#   287.57,
#   300.15,
#   284.82,
#   270.02,
#   302.05,
#   278.15,
#   299.15,
#   299.82,
#   294.26,
#   259.38,
#   249.78,
#   290.15,
#   293.15,
#   283.15,
#   274.15,
#   296.95,
#   256.15,
#   303.15,
#   303.68,
#   281.15,
#   299.15,
#   240.52,
#   297.67,
#   254.27,
#   277.15,
#   299.15,
#   289.82,
#   291.59,
#   268.89,
#   299.15,
#   299.15,
#   284.5,
#   246.03,
#   292.05,
#   292.68,
#   300.18,
#   277.15,
#   287.33,
#   292.15,
#   293.13,
#   272.1,
#   286.48,
#   296.24,
#   266.79,
#   284.2,
#   285.01,
#   301.52,
#   286.48,
#   295.68,
#   298.74,
#   297.04,
#   297.15,
#   296.92,
#   243.35,
#   248.07,
#   272.18,
#   286,
#   280.37,
#   281.48,
#   299.15,
#   296.67,
#   287.59,
#   278.41,
#   276.15,
#   269.15,
#   292.04,
#   262.42,
#   288.15,
#   274.26,
#   301.55,
#   297.15,
#   263.8,
#   288.15,
#   277.15,
#   301.15,
#   306.15,
#   286.86,
#   270.16,
#   268.24,
#   302.16,
#   282.15,
#   269.15,
#   299.15,
#   300.15,
#   284.82,
#   271.68,
#   296.48,
#   263.15,
#   297.81,
#   297.15,
#   297.04,
#   299.15,
#   290.93,
#   295.15,
#   262.15,
#   292.15,
#   292.15,
#   293.71,
#   301.72,
#   299.16,
#   261.59,
#   301.52,
#   301.52,
#   265.37,
#   300.77,
#   270.94,
#   300.59,
#   254.4,
#   301.26,
#   297.04,
#   264.04,
#   262.12,
#   263.16,
#   302.38,
#   255.15,
#   244.39,
#   272.54,
#   294.03,
#   269.15,
#   299.15,
#   296.92,
#   304.15,
#   283.15,
#   286.48,
#   292.77,
#   299.15,
#   258.54,
#   295.51,
#   261.6,
#   242.15,
#   274.83,
#   291.96,
#   290.15,
#   254.15,
#   302.15,
#   279.26,
#   293.71,
#   246.15,
#   275.15,
#   246.15,
#   265.39,
#   302.62,
#   292.04,
#   255.27,
#   291.47,
#   276.41,
#   266.48,
#   300.99,
#   256.15,
#   301.13,
#   247.59,
#   272.15,
#   288.15,
#   296.15,
#   294,
#   298.43,
#   304.15,
#   266.15,
#   268.51,
#   291.15,
#   281.8,
#   298.15,
#   302.95,
#   277.59,
#   273.24,
#   258.15,
#   277.6,
#   290.22,
#   275.15,
#   282.04,
#   287.78,
#   260.15,
#   299.02,
#   265.08,
#   260.13,
#   298.67,
#   299.15,
#   290.15,
#   284.26,
#   281.48,
#   295.03,
#   279.82,
#   289.02,
#   290.65,
#   300.15,
#   300.1,
#   281.48,
#   272.15,
#   290.93,
#   289.26,
#   290.18,
#   257.15,
#   299.97,
#   303.15,
#   283.71,
#   290.37,
#   290.34,
#   295.27,
#   295.21,
#   295.15,
#   303.14,
#   266.26,
#   303.15,
#   283.62,
#   293.15,
#   278.15,
#   290.15,
#   289.26,
#   289.26,
#   284.15,
#   296.81,
#   298.15,
#   279.15,
#   246.15,
#   256.36,
#   296.15,
#   297.72,
#   241.96,
#   289.15,
#   279.26,
#   266.15,
#   239.34,
#   276.4,
#   293.15,
#   293.49,
#   289.35,
#   270.93,
#   264.15,
#   273.71,
#   299.15,
#   299.63,
#   269.98,
#   248.15,
#   297.27,
#   282.15,
#   277.59,
#   299.15,
#   290.86,
#   273.47,
#   263.96,
#   298.15,
#   300.21,
#   293.24,
#   305.37,
#   260.17,
#   299.4,
#   248.32,
#   307.15,
#   298.14,
#   241.5,
#   292.8,
#   285.93,
#   284.83,
#   274.15,
#   277.15,
#   301.15,
#   274.22,
#   245.84,
#   295.43,
#   300.15,
#   292.04,
#   295.16,
#   284.15,
#   303.15,
#   286.72,
#   301.08,
#   286.67,
#   301.15,
#   296.44,
#   300.93,
#   304.01,
#   272.15,
#   279.26,
#   281.15,
#   289.26,
#   264.15,
#   290.15,
#   244.86,
#   293.15,
#   302.11,
#   300.15,
#   298.15,
#   297.04,
#   296.2,
#   285.15,
#   291.63,
#   269.15,
#   285.15,
#   295.15,
#   286.22,
#   277.13,
#   289.3,
#   293.15,
#   294.26,
#   283.15,
#   284.15,
#   300.15,
#   297.25,
#   288.19,
#   258.1,
#   279.34,
#   302.28,
#   263.15,
#   282.59,
#   286.15,
#   296.51,
#   288.15,
#   259.3,
#   295.34,
#   285.93,
#   273.06,
#   264.69,
#   294.15,
#   293.39,
#   276.15,
#   301,
#   304.15,
#   305.93,
#   270.42,
#   290.83,
#   296.15,
#   295.8,
#   244.26,
#   298.15,
#   277.59,
#   251.32,
#   299.15,
#   295.27,
#   300.15,
#   293.75,
#   289.15,
#   278.15,
#   283.57,
#   288.74,
#   289.15,
#   282.58,
#   271.15,
#   295.15,
#   284.15,
#   285.15,
#   271.14,
#   298.15,
#   303.44,
#   290.15,
#   297.42,
#   287.15,
#   295.06,
#   244.26,
#   284.52,
#   271.61,
#   306.15,
#   289.98,
#   261.31,
#   284.15,
#   258.71,
#   287.15,
#   269.15,
#   303.53,
#   294.61,
#   285.15,
#   275.33,
#   241.15,
#   270.35,
#   295.93,
#   260.15,
#   280.15,
#   304.26,
#   298,
#   295.5,
#   287.36,
#   301.11,
#   264.71,
#   292.15,
#   307.16,
#   292.04,
#   290.37,
#   302.4,
#   302.69,
#   301.15,
#   288.15,
#   298.45,
#   302.07,
#   297.68,
#   290.19,
#   278.17,
#   290.03,
#   279.82,
#   306.54,
#   290.56,
#   288.32,
#   300.15,
#   290.78,
#   262.98,
#   300.02,
#   297.22,
#   301.15,
#   271.98,
#   302.11,
#   287.15,
#   266.59,
#   274.75,
#   280.15,
#   305.46,
#   272.24,
#   298.71,
#   301.39,
#   299.26,
#   267.69,
#   276.84,
#   273.83,
#   286.15,
#   287.15,
#   297.3,
#   294.69,
#   276.15,
#   299.15,
#   272.04,
#   299.13,
#   306.1,
#   298.15,
#   281.15,
#   272.71,
#   299.41,
#   271.15,
#   294.15,
#   281.48,
#   277.15,
#   291.15,
#   287.15,
#   275.37,
#   306.15,
#   298.36,
#   298.15,
#   299.15,
#   278.15,
#   252.15,
#   273.15,
#   289.15,
#   278.25,
#   280.96,
#   294.32,
#   276.48,
#   281.48,
#   294.17,
#   279.82,
#   276.15,
#   279.15,
#   297.18,
#   291.15,
#   301.52,
#   303.15,
#   297.15,
#   299.26,
#   304.15,
#   247.27,
#   298.95,
#   298.15,
#   305.15,
#   279.26,
#   288.15,
#   302.04,
#   272.15,
#   255.91,
#   302.49,
#   285.93,
#   291.48,
#   279.82,
#   289.82,
#   267.99,
#   266.15,
#   272.15,
#   283.15,
#   260.02,
#   273.42,
#   302.95,
#   263.57,
#   293.62,
#   280.93,
#   264.1,
#   296.12,
#   267.49,
#   295.15,
#   307.15,
#   288.71,
#   309.81,
#   284.82,
#   286.48,
#   274.7,
#   277.04,
#   283.15,
#   288.15,
#   247.89,
#   303.15,
#   296.36,
#   290.33,
#   296.15,
#   299.15,
#   277.15,
#   298.62,
#   300.16,
#   299.15,
#   277.59,
#   298.87,
#   280.93,
#   270,
#   280.37,
#   283.15,
#   279.26],
#  'Wind Speed': [9.3,
#   3.6,
#   2.1,
#   5.7,
#   4.87,
#   5.74,
#   4.6,
#   2,
#   8.33,
#   2.28,
#   9.3,
#   2.27,
#   0.76,
#   1.04,
#   2.68,
#   3.46,
#   4.7,
#   2.6,
#   3.1,
#   0.75,
#   3.81,
#   3.6,
#   9.8,
#   2.1,
#   5,
#   5.7,
#   1.78,
#   1.79,
#   3.49,
#   11.43,
#   6.66,
#   1.3,
#   3.1,
#   3.61,
#   1.5,
#   6.2,
#   4.13,
#   4.1,
#   6.64,
#   10.3,
#   5.64,
#   3.42,
#   1.78,
#   3.93,
#   2.6,
#   5.1,
#   1.19,
#   9.3,
#   9.3,
#   1.16,
#   8.7,
#   5.1,
#   3.6,
#   3.13,
#   0.79,
#   3.38,
#   0.83,
#   5.1,
#   2.6,
#   3,
#   12.3,
#   1.86,
#   3.1,
#   1.36,
#   2.55,
#   4.6,
#   7.2,
#   2.2,
#   0.77,
#   1.93,
#   6.2,
#   2.1,
#   3.6,
#   4.55,
#   5.7,
#   6.2,
#   1.5,
#   2.43,
#   5.63,
#   1.54,
#   1.3,
#   0.94,
#   6.7,
#   2.26,
#   7.2,
#   7.34,
#   10.11,
#   2.68,
#   6.4,
#   5.65,
#   6.25,
#   3.68,
#   3.11,
#   4.1,
#   1.21,
#   1.18,
#   4.02,
#   3.6,
#   1.24,
#   2.42,
#   1.54,
#   1.57,
#   8.05,
#   3.13,
#   1.22,
#   2.1,
#   3.63,
#   0.97,
#   5.89,
#   3.6,
#   2.1,
#   0.89,
#   1.32,
#   0.35,
#   2.6,
#   4.8,
#   3.1,
#   6.18,
#   0.89,
#   4.12,
#   3.6,
#   4.6,
#   1.13,
#   3.31,
#   3.17,
#   6.36,
#   6.2,
#   2.1,
#   2.1,
#   1,
#   7.2,
#   9.21,
#   2.24,
#   14,
#   2.44,
#   8.23,
#   2.6,
#   5.7,
#   3.6,
#   3.1,
#   0.5,
#   2.6,
#   3.85,
#   5.7,
#   5.55,
#   2.48,
#   3.17,
#   4.57,
#   1.52,
#   0.89,
#   2.43,
#   7.3,
#   5.03,
#   1.6,
#   4.48,
#   2.6,
#   2.99,
#   5.1,
#   3.02,
#   5,
#   3.1,
#   3.43,
#   9.21,
#   2.48,
#   11.3,
#   5.7,
#   1.24,
#   3.1,
#   4.6,
#   2.68,
#   1.71,
#   8.7,
#   1.4,
#   3.35,
#   1.09,
#   1.5,
#   5.67,
#   2.26,
#   4.6,
#   2.6,
#   2.6,
#   6.7,
#   3.6,
#   5.7,
#   5,
#   3,
#   1.72,
#   0.62,
#   6.7,
#   2.65,
#   1.1,
#   13.33,
#   3.1,
#   4.46,
#   4.1,
#   6.98,
#   3,
#   2.1,
#   8.2,
#   3.1,
#   3.17,
#   7.02,
#   5.12,
#   11.3,
#   3.49,
#   7.2,
#   3.67,
#   1.5,
#   4.62,
#   1,
#   2.73,
#   1.5,
#   2.94,
#   1.14,
#   4,
#   3.6,
#   5.02,
#   1.46,
#   0.09,
#   4.64,
#   3.47,
#   8.88,
#   2.1,
#   4.1,
#   3.1,
#   1,
#   0.98,
#   8.05,
#   2.25,
#   6.7,
#   1.5,
#   7.38,
#   1.67,
#   2.1,
#   1.58,
#   2.1,
#   1.64,
#   4.6,
#   7.93,
#   1.5,
#   1.56,
#   3.6,
#   3.86,
#   6.82,
#   4.3,
#   11.47,
#   3.31,
#   1.16,
#   4.6,
#   5.18,
#   6.2,
#   10.3,
#   8.2,
#   1.5,
#   5.1,
#   7.2,
#   1.43,
#   6.7,
#   2.1,
#   3,
#   1.15,
#   6.7,
#   6.39,
#   2.12,
#   2.6,
#   8.7,
#   1,
#   0.43,
#   3.16,
#   2.6,
#   6.72,
#   2.46,
#   1.31,
#   1.59,
#   2.1,
#   2.1,
#   3.15,
#   3.14,
#   2.1,
#   4.12,
#   5.1,
#   1,
#   5.7,
#   0.98,
#   5.65,
#   5.77,
#   0.5,
#   9.82,
#   5.05,
#   4.1,
#   0.82,
#   3.93,
#   0.74,
#   2.1,
#   3.64,
#   4.5,
#   6.65,
#   2.1,
#   1.18,
#   12.3,
#   6.7,
#   2.1,
#   2.47,
#   2.27,
#   0.18,
#   1.5,
#   0.45,
#   3.95,
#   1.5,
#   0.5,
#   10.09,
#   2.48,
#   3.1,
#   2.6,
#   3.42,
#   4.9,
#   2.19,
#   6.2,
#   2.1,
#   3.14,
#   0.45,
#   2.04,
#   4.6,
#   0.97,
#   2.6,
#   1.32,
#   3.6,
#   2.6,
#   0.89,
#   3.56,
#   9.8,
#   7.66,
#   1.5,
#   6.7,
#   1,
#   1.2,
#   4.56,
#   5.55,
#   3.1,
#   6.81,
#   2.24,
#   5.74,
#   5.1,
#   1.26,
#   2.23,
#   1.96,
#   0.51,
#   12.04,
#   14,
#   6.2,
#   1,
#   2.65,
#   4.1,
#   0.91,
#   0.66,
#   1,
#   2.62,
#   7.71,
#   1.45,
#   1.74,
#   1.5,
#   6.54,
#   4.1,
#   2.6,
#   0.8,
#   2.94,
#   5.7,
#   3.05,
#   4.6,
#   3.1,
#   0.45,
#   2.83,
#   2.1,
#   0.77,
#   1.5,
#   0.64,
#   4.1,
#   5.1,
#   7.86,
#   0.5,
#   1,
#   2.33,
#   4.6,
#   2.66,
#   2.6,
#   7.7,
#   7.93,
#   3.6,
#   1.58,
#   1.5,
#   1.51,
#   2.28,
#   1.05,
#   2.06,
#   0.67,
#   8.92,
#   4.1,
#   3.29,
#   2.42,
#   1.5,
#   2.4,
#   4.31,
#   1,
#   3.81,
#   1.8,
#   5.7,
#   2.95,
#   1.5,
#   8.78,
#   2.24,
#   4,
#   3.6,
#   5.1,
#   0.13,
#   3.6,
#   1.29,
#   6,
#   4.19,
#   5.7,
#   1.02,
#   1.46,
#   2.1,
#   2.16,
#   1.45,
#   5.1,
#   2.1,
#   1.56,
#   4.63,
#   2.44,
#   0.47,
#   5.68,
#   2.14,
#   4.02,
#   1.48,
#   1.98,
#   2.87,
#   1.5,
#   1.46,
#   3.22,
#   2.9,
#   6.32,
#   1,
#   5.92,
#   5.06,
#   2.1,
#   1.04,
#   2.27,
#   7.2,
#   2.22,
#   1.23,
#   4.6,
#   5.51,
#   2.6,
#   2.3,
#   4.74,
#   3.65,
#   3.6,
#   6.2,
#   5.61,
#   3.9,
#   2.6,
#   5.1,
#   8.2,
#   7.94,
#   2.11,
#   1.5,
#   4.1,
#   0.94,
#   3.72,
#   5.1,
#   2.1,
#   3.6,
#   7.7,
#   2.1,
#   4.6,
#   1.79,
#   3.6,
#   6.78,
#   3.6,
#   5.1,
#   2.1,
#   2.59,
#   2.6,
#   6.7,
#   1.96,
#   2.87,
#   0.83,
#   8.2,
#   2.6,
#   0.94,
#   4.6,
#   1.5,
#   4,
#   12.98,
#   4.6,
#   4.57,
#   5.1,
#   2.1,
#   5.1,
#   1.5,
#   1.8,
#   1.63,
#   2.6,
#   2.1,
#   2,
#   4.1,
#   4.6,
#   1,
#   6.29,
#   3.7,
#   2.25,
#   3.6,
#   0.89,
#   4.1,
#   2.33,
#   2.6,
#   5.1,
#   5.1,
#   4.47,
#   18.56,
#   2.59,
#   2.19,
#   4.63,
#   1.5,
#   5.13,
#   1.08,
#   1.94,
#   1,
#   4.1,
#   6.7,
#   0.37,
#   9.8,
#   6.2,
#   2.26,
#   0.5,
#   5.1,
#   4.1,
#   0.59,
#   3.6,
#   0.3,
#   0.24,
#   1.64,
#   2.1,
#   6.2,
#   0.94,
#   4.03,
#   3.34,
#   1.5,
#   6.69,
#   1,
#   3.05,
#   6.2,
#   1,
#   9.3]}

# %%
''' 
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "London"

# Build query URL
query_url = url + "appid=" + weather_api_key + "&q=" + city

response = requests.get(query_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
'''
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 51.51,
#         "lon": -0.13
#     },
#     "dt": 1583882584,
#     "id": 2643743,
#     "main": {
#         "feels_like": 279.27,
#         "humidity": 87,
#         "pressure": 1008,
#         "temp": 283.29,
#         "temp_max": 285.15,
#         "temp_min": 281.48
#     },
#     "name": "London",
#     "sys": {
#         "country": "GB",
#         "id": 1414,
#         "sunrise": 1583821515,
#         "sunset": 1583862983,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "speed": 5.1
#     }
# }

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df = pd.DataFrame(data)
city_data_df
# Out:
#                City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Saint-Philippe          75      RE  1583896216        69 -21.36   55.77
# 1      Punta Arenas          75      CL  1583896216        75 -53.15  -70.92
# 2          Nānākuli          90      US  1583896216        78  21.39 -158.15
# 3         Mahébourg          75      MU  1583896216        94 -20.41   57.70
# 4           Kuruman           0      ZA  1583896216        73 -27.45   23.43
# ..              ...         ...     ...         ...       ...    ...     ...
# 549          Ugento          40      IT  1583896254        93  39.93   18.16
# 550     Derzhavīnsk         100      KZ  1583896255        96  51.10   66.32
# 551         Kilcock          40      IE  1583896255        75  53.40   -6.67
# 552          Buochs          75      CH  1583896255        93  46.97    8.42
# 553         Fairlie          20      GB  1583896255        75  55.76   -4.86
#
#      Max Temp  Wind Speed
# 0      300.15        9.30
# 1      282.04        3.60
# 2      299.15        2.10
# 3      299.15        5.70
# 4      288.23        4.87
# ..        ...         ...
# 549    280.93        1.00
# 550    270.00        3.05
# 551    280.37        6.20
# 552    283.15        1.00
# 553    279.26        9.30
#
# [554 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
